# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load input file

# %%
dfraw = pd.read_csv("v1-start.csv")

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
dfraw.head()
# Out:
#   external_id type    name_1                   name_2               name_3  \
# 0         NaN  NaN  Passito           Château d´Yquem                  NaN
# 1         NaN  NaN  Passito           Château d´Yquem                  NaN
# 2         NaN  NaN  Passito   Cashmere Gewürztraminer  Weingut Elena Walch
# 3         NaN  NaN  Passito      Ornus dell Ornelaia        Petit Manseng
# 4         NaN  NaN  Passito      Ornus dell Ornelaia        Petit Manseng
#
#   internal_notes  vintage info bottle_price magnum_price demi_price  \
# 0      Sauternes   2004.0  NaN          NaN          NaN        NaN
# 1      Sauternes   2001.0  NaN          NaN          NaN        NaN
# 2       PASSITO    2020.0  NaN     19.00 €           NaN        NaN
# 3       PASSITO    2016.0  NaN          NaN    110.00 €         NaN
# 4       PASSITO    2015.0  NaN          NaN          NaN        NaN
#
#    bottle_qty  magnum_qty  demi_qty purchase_price  to_archive
# 0         2.0         NaN       NaN            NaN         NaN
# 1         4.0         NaN       NaN            NaN         NaN
# 2         0.0         NaN       NaN            NaN         1.0
# 3        26.0         NaN       NaN            NaN         NaN
# 4         4.0         NaN       NaN            NaN         NaN

# %%
# Create a new dataframe to store the expanded rows
expanded_rows = []

# Iterate through each row in the original dataframe
for _, row in dfraw.iterrows():
    # Add the original row
    base_row = {
        'external_id': row['external_id'],
        'type': row['type'],
        'full_name': ('' if pd.isna(row['name_1']) else str(row['name_1'])) + ' ' + 
                    ('' if pd.isna(row['name_2']) else str(row['name_2'])) + ' ' + 
                    ('' if pd.isna(row['name_3']) else str(row['name_3'])),
        'vintage': row['vintage'],
        'info': row['info'],
        'internal_notes': row['internal_notes'],
        'purchase_price': row['purchase_price']
    }
    
    # Check each bottle size and add new rows if quantity exists
    bottle_qty = 0 if pd.isna(row['bottle_qty']) else float(row['bottle_qty'])
    if bottle_qty > 0:
        bottle_row = base_row.copy()
        bottle_row['size'] = 'BOTTLE'
        bottle_row['price'] = row['bottle_price']
        bottle_row['quantity'] = bottle_qty
        expanded_rows.append(bottle_row)
    elif pd.notna(row['to_archive']) and float(row['to_archive']) == 1:
        bottle_row = base_row.copy()
        bottle_row['size'] = 'BOTTLE'
        bottle_row['price'] = row['bottle_price']
        bottle_row['quantity'] = 0
        expanded_rows.append(bottle_row)

        
    magnum_qty = 0 if pd.isna(row['magnum_qty']) else float(row['magnum_qty'])
    if magnum_qty > 0:
        magnum_row = base_row.copy()
        magnum_row['size'] = 'MAGNUM'
        magnum_row['price'] = row['magnum_price']
        magnum_row['quantity'] = magnum_qty
        expanded_rows.append(magnum_row)
    elif pd.notna(row['to_archive']) and float(row['to_archive']) == 1:
        magnum_row = base_row.copy()
        magnum_row['size'] = 'MAGNUM'
        magnum_row['price'] = row['magnum_price']
        magnum_row['quantity'] = 0
        expanded_rows.append(magnum_row)
        
    demi_qty = 0 if pd.isna(row['demi_qty']) else float(row['demi_qty'])
    if demi_qty > 0:
        demi_row = base_row.copy()
        demi_row['size'] = 'HALF_BOTTLE'
        demi_row['price'] = row['demi_price']
        demi_row['quantity'] = demi_qty
        expanded_rows.append(demi_row)
    elif pd.notna(row['to_archive']) and float(row['to_archive']) == 1:
        demi_row = base_row.copy()
        demi_row['size'] = 'HALF_BOTTLE'
        demi_row['price'] = row['demi_price']
        demi_row['quantity'] = 0
        expanded_rows.append(demi_row)

# Create the new dataframe with expanded rows
df1 = pd.DataFrame(expanded_rows)

df1.head(26)
# Out:
#    external_id type                                          full_name  \
# 0          NaN  NaN                          Passito  Château d´Yquem
# 1          NaN  NaN                          Passito  Château d´Yquem
# 2          NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 3          NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 4          NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 5          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 6          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 7          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 8          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 9          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 10         NaN  NaN    Passito  Rosenmuskateller Weingut Alois Lageder
# 11         111  NaN                     Prosecco Bepin De Eto PROSECCO
# 12         114  NaN      Prosecco Bepin De Eto Rosato  SPUMANTE ROSATO
# 13         112  NaN              Prosecco Le Colture PROSECCO CARTIZZE
# 14         NaN  NaN  Moscato d´Asti Giacomo Bologna - Braida MOSCAT...
# 15         119  NaN  Moscato d´Asti Giacomo Bologna - Braida MOSCAT...
# 16         NaN  NaN         Lambrusco Reggiano Medici Ermete CONCERTO
# 17         100  NaN                   Sektmanufaktur Winkler LAMM N.12
# 18         NaN  NaN                               Ferrari  Cuvée Zero
# 19         NaN  NaN                                Ferrari  Millesime
# 20         NaN  NaN                                Ferrari  Millesime
# 21         NaN  NaN                                Ferrari  Millesime
# 22         101  NaN                                      Ferrari PERLE
# 23         101  NaN                                      Ferrari PERLE
# 24         NaN  NaN                                      Ferrari PERLE
# 25         NaN  NaN                                      Ferrari PERLE
#
#     vintage info         internal_notes purchase_price         size  \
# 0    2004.0  NaN              Sauternes            NaN       BOTTLE
# 1    2001.0  NaN              Sauternes            NaN       BOTTLE
# 2    2020.0  NaN               PASSITO             NaN       BOTTLE
# 3    2020.0  NaN               PASSITO             NaN       MAGNUM
# 4    2020.0  NaN               PASSITO             NaN  HALF_BOTTLE
# 5    2016.0  NaN               PASSITO             NaN       BOTTLE
# 6    2015.0  NaN               PASSITO             NaN       BOTTLE
# 7    2011.0  NaN               PASSITO             NaN       BOTTLE
# 8    2010.0  NaN               PASSITO             NaN       BOTTLE
# 9    2009.0  NaN               PASSITO             NaN       BOTTLE
# 10   2008.0  NaN               PASSITO             NaN       BOTTLE
# 11      NaN  NaN   Superiore Brut DOCG         8.30 €        BOTTLE
# 12      NaN  NaN      Millesimato ROSÉ         8.30 €        BOTTLE
# 13      NaN  NaN        Superiore DOCG             NaN       BOTTLE
# 14   2024.0  NaN                    NaN            NaN       BOTTLE
# 15   2022.0  NaN                    NaN            NaN       BOTTLE
# 16   2021.0  NaN                    NaN            NaN       BOTTLE
# 17      NaN  NaN                    NaN            NaN       BOTTLE
# 18   2015.0  NaN                    NaN            NaN       BOTTLE
# 19   2005.0  NaN                    NaN            NaN       BOTTLE
# 20   2004.0  NaN                    NaN            NaN       BOTTLE
# 21   2003.0  NaN                    NaN            NaN       BOTTLE
# 22   2018.0  NaN               MAGNUM              NaN       BOTTLE
# 23   2018.0  NaN               MAGNUM              NaN       MAGNUM
# 24   2013.0  NaN               MAGNUM              NaN       MAGNUM
# 25   2011.0  NaN               MAGNUM              NaN       MAGNUM
#
#          price  quantity
# 0          NaN       2.0
# 1          NaN       4.0
# 2     19.00 €        0.0
# 3          NaN       0.0
# 4          NaN       0.0
# 5          NaN      26.0
# 6          NaN       4.0
# 7     19.00 €        4.0
# 8          NaN       3.0
# 9          NaN       1.0
# 10    19.00 €        7.0
# 11    41.00 €       60.0
# 12    43.00 €       60.0
# 13    50.00 €        5.0
# 14         NaN      18.0
# 15    45.00 €        2.0
# 16    41.00 €        1.0
# 17    50.00 €        3.0
# 18         NaN      13.0
# 19         NaN       1.0
# 20         NaN       1.0
# 21         NaN       1.0
# 22    69.00 €      145.0
# 23         NaN      12.0
# 24         NaN       1.0
# 25   150.00 €        1.0

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
# copy values from original columns to new columns
df['external_id'] = None
df['type'] = df1['type']
df['name'] = df1['full_name'].replace(' nan ', '')
df['winery_name'] = None
df["size"] = df1["size"]
df["vintage"] = df1["vintage"]
df["quantity"] = df1["quantity"]
df["storage_area"] = None
df["info"] = df1["info"]
df["internal_notes"] = df1["internal_notes"]
df["visible"] = True

df.head()
# Out:
#   external_id type                                               name  \
# 0         NaN  NaN                          Passito  Château d´Yquem
# 1         NaN  NaN                          Passito  Château d´Yquem
# 2         NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 3         NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 4         NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
#
#   winery_name info         size  vintage price purchase_price  quantity  \
# 0        None  NaN       BOTTLE   2004.0   NaN            NaN       2.0
# 1        None  NaN       BOTTLE   2001.0   NaN            NaN       4.0
# 2        None  NaN       BOTTLE   2020.0   NaN            NaN       0.0
# 3        None  NaN       MAGNUM   2020.0   NaN            NaN       0.0
# 4        None  NaN  HALF_BOTTLE   2020.0   NaN            NaN       0.0
#
#   storage_area internal_notes  visible
# 0         None      Sauternes     True
# 1         None      Sauternes     True
# 2         None       PASSITO      True
# 3         None       PASSITO      True
# 4         None       PASSITO      True

# %%
df1['price'] = df1['price'].fillna(0)
df['price'] = df1['price'].apply(lambda x: int(float(str(x).replace('€', '').replace(',', ''))*100)) # convert to cents

df1['purchase_price'] = df1['purchase_price'].fillna(0)
df['purchase_price'] = df1['purchase_price'].apply(lambda x: int(float(str(x).replace('€', '').replace(',', ''))*100)) # convert to cents

df.head(12)
# Out:
#    external_id type                                               name  \
# 0          NaN  NaN                          Passito  Château d´Yquem
# 1          NaN  NaN                          Passito  Château d´Yquem
# 2          NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 3          NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 4          NaN  NaN  Passito  Cashmere Gewürztraminer Weingut Elena...
# 5          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 6          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 7          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 8          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 9          NaN  NaN      Passito  Ornus dell Ornelaia   Petit Manseng
# 10         NaN  NaN    Passito  Rosenmuskateller Weingut Alois Lageder
# 11         NaN  NaN                     Prosecco Bepin De Eto PROSECCO
#
#    winery_name info         size  vintage  price  purchase_price  quantity  \
# 0         None  NaN       BOTTLE   2004.0      0               0       2.0
# 1         None  NaN       BOTTLE   2001.0      0               0       4.0
# 2         None  NaN       BOTTLE   2020.0   1900               0       0.0
# 3         None  NaN       MAGNUM   2020.0      0               0       0.0
# 4         None  NaN  HALF_BOTTLE   2020.0      0               0       0.0
# 5         None  NaN       BOTTLE   2016.0      0               0      26.0
# 6         None  NaN       BOTTLE   2015.0      0               0       4.0
# 7         None  NaN       BOTTLE   2011.0   1900               0       4.0
# 8         None  NaN       BOTTLE   2010.0      0               0       3.0
# 9         None  NaN       BOTTLE   2009.0      0               0       1.0
# 10        None  NaN       BOTTLE   2008.0   1900               0       7.0
# 11        None  NaN       BOTTLE      NaN   4100             830      60.0
#
#    storage_area         internal_notes  visible
# 0          None              Sauternes     True
# 1          None              Sauternes     True
# 2          None               PASSITO      True
# 3          None               PASSITO      True
# 4          None               PASSITO      True
# 5          None               PASSITO      True
# 6          None               PASSITO      True
# 7          None               PASSITO      True
# 8          None               PASSITO      True
# 9          None               PASSITO      True
# 10         None               PASSITO      True
# 11         None   Superiore Brut DOCG      True

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id type                                               name  \
# 0                                           Passito  Château d´Yquem
# 1                                           Passito  Château d´Yquem
# 2                   Passito  Cashmere Gewürztraminer Weingut Elena...
# 3                   Passito  Cashmere Gewürztraminer Weingut Elena...
# 4                   Passito  Cashmere Gewürztraminer Weingut Elena...
#
#   winery_name info         size  vintage  price  purchase_price  quantity  \
# 0                        BOTTLE     2004      0               0         2
# 1                        BOTTLE     2001      0               0         4
# 2                        BOTTLE     2020   1900               0         0
# 3                        MAGNUM     2020      0               0         0
# 4                   HALF_BOTTLE     2020      0               0         0
#
#   storage_area internal_notes  visible
# 0                   Sauternes     True
# 1                   Sauternes     True
# 2                    PASSITO      True
# 3                    PASSITO      True
# 4                    PASSITO      True

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
