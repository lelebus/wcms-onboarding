# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head()
# Out:
#   type                              winery  \
# 0  RED  Agricoltori del Chianti Geografico
# 1  RED                           Allegrini
# 2  RED                           Allegrini
# 3  RED                           Allegrini
# 4  RED                           Allegrini
#
#                                         name size  vintage supplier price_eur  \
# 0                           Chianti Classico  NaN   1971.0      NaN       NaN
# 1   Amarone della Valpolicella Classico docg  NaN   2017.0      NaN     150 €
# 2  Amarone della Valpolicella Classico docg   NaN   2019.0      NaN     120 €
# 3                La Grola igt Rosso Veronese  NaN   2018.0      NaN       NaN
# 4                La Grola igt Rosso Veronese  NaN   2019.0      NaN      45 €
#
#     qty   Storage_1 Storage_2 Storage_3 purchase_price_inclvat
# 0   1.0  Collezione       NaN       NaN                   1 €
# 1   4.0  s2 - legno       NaN       NaN                  76 €
# 2   5.0  s2 - legno       NaN       NaN                  53 €
# 3   NaN         NaN       NaN       NaN                    NaN
# 4  17.0          s4    bar005       NaN                  18 €

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
# copy values from original columns to new columns
df['external_id'] = None
df['type'] = df1['type']
df['name'] = df1['name']
df['winery_name'] = df1['winery']
df["size"] = df1["size"]
df["vintage"] = df1["vintage"]
df["quantity"] = df1["qty"]
df["storage_area"] = df1.apply(lambda x: str(x["Storage_1"]) + ("+" + str(x["Storage_2"]) if pd.notna(x["Storage_2"]) else "") + ("+" + str(x["Storage_3"]) if pd.notna(x["Storage_3"]) else ""), axis=1)
df["info"] = None
df["internal_notes"] = df1.apply(lambda x: "Fornitore: " + x["supplier"] if pd.notna(x["supplier"]) else None, axis=1)
df["visible"] = True

df.head()
# Out:
#   external_id type                                       name  \
# 0         NaN  RED                           Chianti Classico
# 1         NaN  RED   Amarone della Valpolicella Classico docg
# 2         NaN  RED  Amarone della Valpolicella Classico docg
# 3         NaN  RED                La Grola igt Rosso Veronese
# 4         NaN  RED                La Grola igt Rosso Veronese
#
#                           winery_name  info size  vintage price  \
# 0  Agricoltori del Chianti Geografico  None  NaN   1971.0   NaN
# 1                           Allegrini  None  NaN   2017.0   NaN
# 2                           Allegrini  None  NaN   2019.0   NaN
# 3                           Allegrini  None  NaN   2018.0   NaN
# 4                           Allegrini  None  NaN   2019.0   NaN
#
#   purchase_price  quantity storage_area internal_notes  visible
# 0            NaN       1.0   Collezione           None     True
# 1            NaN       4.0   s2 - legno           None     True
# 2            NaN       5.0   s2 - legno           None     True
# 3            NaN       NaN          nan           None     True
# 4            NaN      17.0    s4+bar005           None     True

# %%
# fill size with BOTTLE
df['size'] = df['size'].fillna('BOTTLE')

# %%
df1['price_eur'] = df1['price_eur'].fillna(0)
df['price'] = df1['price_eur'].apply(lambda x: int(float(str(x).replace('€', '').replace(',', ''))*100)) # convert to cents

df['purchase_price_inclvat'] = df1['purchase_price_inclvat'].fillna(0)
df['purchase_price'] = df1['purchase_price_inclvat'].apply(lambda x: int(float(str(x).replace('€', '').replace(',', '').strip())*100/1.22) if pd.notna(x) else 0) # convert to cents and remove 22% VAT

df.head()
# Out:
#   external_id type                                       name  \
# 0         NaN  RED                           Chianti Classico
# 1         NaN  RED   Amarone della Valpolicella Classico docg
# 2         NaN  RED  Amarone della Valpolicella Classico docg
# 3         NaN  RED                La Grola igt Rosso Veronese
# 4         NaN  RED                La Grola igt Rosso Veronese
#
#                           winery_name  info    size  vintage  price  \
# 0  Agricoltori del Chianti Geografico  None  BOTTLE   1971.0      0
# 1                           Allegrini  None  BOTTLE   2017.0  15000
# 2                           Allegrini  None  BOTTLE   2019.0  12000
# 3                           Allegrini  None  BOTTLE   2018.0      0
# 4                           Allegrini  None  BOTTLE   2019.0   4500
#
#    purchase_price  quantity storage_area internal_notes  visible  \
# 0              81       1.0   Collezione           None     True
# 1            6229       4.0   s2 - legno           None     True
# 2            4344       5.0   s2 - legno           None     True
# 3               0       NaN          nan           None     True
# 4            1475      17.0    s4+bar005           None     True
#
#   purchase_price_inclvat
# 0                   1 €
# 1                  76 €
# 2                  53 €
# 3                      0
# 4                  18 €

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id type                                       name  \
# 0              RED                           Chianti Classico
# 1              RED   Amarone della Valpolicella Classico docg
# 2              RED  Amarone della Valpolicella Classico docg
# 3              RED                La Grola igt Rosso Veronese
# 4              RED                La Grola igt Rosso Veronese
#
#                           winery_name info    size  vintage  price  \
# 0  Agricoltori del Chianti Geografico       BOTTLE     1971      0
# 1                           Allegrini       BOTTLE     2017  15000
# 2                           Allegrini       BOTTLE     2019  12000
# 3                           Allegrini       BOTTLE     2018      0
# 4                           Allegrini       BOTTLE     2019   4500
#
#    purchase_price  quantity storage_area internal_notes  visible  \
# 0              81         1   Collezione                    True
# 1            6229         4   s2 - legno                    True
# 2            4344         5   s2 - legno                    True
# 3               0         0          nan                    True
# 4            1475        17    s4+bar005                    True
#
#   purchase_price_inclvat
# 0                   1 €
# 1                  76 €
# 2                  53 €
# 3                      0
# 4                  18 €

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
