# %% [markdown]
# # Prepare wines from a dirty list
#
# Load a CSV of wines (aka winelist) and clean the data to get it ready to run it through the matching algorithm.

# %%
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load dirty winelist file and perform cleaning

# %%
wines = pd.read_csv('v1-cleaned.csv')
print(f'Total rows: {wines.shape[0]}')
print()

wines.head()
# Out:
# Total rows: 210
#     external_id type    name_one       name_two     Stato        Zona
# 0  8.767565e+10  NaN       ANJOU       EFFUSION   FRANCIA       LOIRA  \
# 1  8.796437e+10  NaN       ANJOU  LE CORNILLARD   FRANCIA       LOIRA
# 2  7.677869e+13  NaN      ARNEIS   ROERO ARNEIS  PIEMONTE       ROERO
# 3           NaN  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
# 4  8.033255e+12  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
#
#                     winery_name  vintage  size  price   cost  quantity
# 0      DOMAINE PATRICK BAUDOUIN   2021.0  0,75     55   25.5       3.0
# 1      DOMAINE PATRICK BAUDOUIN   2020.0  0,75     90   39.5       3.0
# 2             GIACOMO FENOCCHIO   2022.0  0,75     28   11.0      16.0
# 3  AZ FALLETTO DI BRUNO GIACOSA   2015.0  0,75    200  135.0       1.0
# 4                       CERETTO   2018.0    MG    190   98.0       2.0

# %% [markdown]
# We need the following fields:
#
# - `external_id`
# - `name`
# - `winery_name`
# - `type`
# - `storage_area`
# - `size`
# - `vintage`
# - `price`
# - `info`
# - `quantity`
# - `internal_notes`
#
# ---

# %% [markdown]
# ### Note: This part is always CUSTOM to the client

# %% [markdown]
# - Merge name_one and name_two.
#
# Other fields:
# - external_id OK
# - type OK
# - name: merge name_one + name_two
# - winery_name OK
# - storage_area missing
# - size to parse
# - vintage drop if not a number
# - price in euros
# - info missing
# - quantity OK
# - internal_notes contains the purchase price. Add a label

# %%
import re

# merge name_one and name_two into name
wines['name'] = wines['name_one'].fillna('') + ' ' + wines['name_two'].fillna('')
wines['name'] = wines['name'].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

wines.head()
# Out:
#     external_id type    name_one       name_two     Stato        Zona
# 0  8.767565e+10  NaN       ANJOU       EFFUSION   FRANCIA       LOIRA  \
# 1  8.796437e+10  NaN       ANJOU  LE CORNILLARD   FRANCIA       LOIRA
# 2  7.677869e+13  NaN      ARNEIS   ROERO ARNEIS  PIEMONTE       ROERO
# 3           NaN  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
# 4  8.033255e+12  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
#
#                     winery_name  vintage  size  price   cost  quantity
# 0      DOMAINE PATRICK BAUDOUIN   2021.0  0,75     55   25.5       3.0  \
# 1      DOMAINE PATRICK BAUDOUIN   2020.0  0,75     90   39.5       3.0
# 2             GIACOMO FENOCCHIO   2022.0  0,75     28   11.0      16.0
# 3  AZ FALLETTO DI BRUNO GIACOSA   2015.0  0,75    200  135.0       1.0
# 4                       CERETTO   2018.0    MG    190   98.0       2.0
#
#                   name
# 0       ANJOU EFFUSION
# 1  ANJOU LE CORNILLARD
# 2  ARNEIS ROERO ARNEIS
# 3     BARBARESCO ASILI
# 4     BARBARESCO ASILI

# %%
import math

# add empty area
wines['storage_area'] = ''

# add empty info
wines['info'] = ''

# set 0 vintage year to None and NaN vintage year to None
wines['vintage'] = wines['vintage'].apply(lambda x: None if pd.isnull(x) or pd.isna(x) else int(x))

# add label to purchase price in internal_notes
wines['internal_notes'] = wines['cost'].apply(lambda x: f'Purchase Price: {x}')

wines.head(68)
# Out:
#      external_id       type        name_one                     name_two
# 0   8.767565e+10        NaN           ANJOU                     EFFUSION  \
# 1   8.796437e+10        NaN           ANJOU                LE CORNILLARD
# 2   7.677869e+13        NaN          ARNEIS                 ROERO ARNEIS
# 3            NaN        RED      BARBARESCO                        ASILI
# 4   8.033255e+12        RED      BARBARESCO                        ASILI
# ..           ...        ...             ...                          ...
# 63  8.025494e+12        RED  CABERNET FRANC               CABERNET FRANC
# 64  8.765466e+13  SPARKLING       CHAMPAGNE              BLANC DE BLANCS
# 65  5.678976e+09  SPARKLING       CHAMPAGNE  BLANC DE BLANCS EB GRAN CRU
# 66  3.760105e+12  SPARKLING       CHAMPAGNE     BLANC DE BLANCS GRAN CRU
# 67  7.698579e+13  SPARKLING       CHAMPAGNE  BLANC DE BLANCS GRAN CRU EB
#
#                     Stato        Zona                   winery_name  vintage
# 0                 FRANCIA       LOIRA      DOMAINE PATRICK BAUDOUIN   2021.0  \
# 1                 FRANCIA       LOIRA      DOMAINE PATRICK BAUDOUIN   2020.0
# 2                PIEMONTE       ROERO             GIACOMO FENOCCHIO   2022.0
# 3                PIEMONTE  BARBARESCO  AZ FALLETTO DI BRUNO GIACOSA   2015.0
# 4                PIEMONTE  BARBARESCO                       CERETTO   2018.0
# ..                    ...         ...                           ...      ...
# 63  FRIULI VENEZIA GIULIA      COLLIO              RUSSIZ SUPERIORE   2021.0
# 64                FRANCIA   CHAMPAGNE               MAURICE GRUMIER      NaN
# 65                FRANCIA   CHAMPAGNE                     VAUVERSIN      NaN
# 66                FRANCIA   CHAMPAGNE                 LEGRAS & HAAS      NaN
# 67                FRANCIA   CHAMPAGNE                      LEMESNIL      NaN
#
#     size  price   cost  quantity                                   name
# 0   0,75     55   25.5       3.0                         ANJOU EFFUSION  \
# 1   0,75     90   39.5       3.0                    ANJOU LE CORNILLARD
# 2   0,75     28   11.0      16.0                    ARNEIS ROERO ARNEIS
# 3   0,75    200  135.0       1.0                       BARBARESCO ASILI
# 4     MG    190   98.0       2.0                       BARBARESCO ASILI
# ..   ...    ...    ...       ...                                    ...
# 63  0,75     33   12.0      16.0          CABERNET FRANC CABERNET FRANC
# 64  0,75     90   37.0       6.0              CHAMPAGNE BLANC DE BLANCS
# 65  0,75     70   32.0      12.0  CHAMPAGNE BLANC DE BLANCS EB GRAN CRU
# 66  0,75     85   39.0       1.0     CHAMPAGNE BLANC DE BLANCS GRAN CRU
# 67  0,75     75   28.0       5.0  CHAMPAGNE BLANC DE BLANCS GRAN CRU EB
#
#    storage_area info         internal_notes
# 0                      Purchase Price: 25.5
# 1                      Purchase Price: 39.5
# 2                      Purchase Price: 11.0
# 3                     Purchase Price: 135.0
# 4                      Purchase Price: 98.0
# ..          ...  ...                    ...
# 63                     Purchase Price: 12.0
# 64                     Purchase Price: 37.0
# 65                     Purchase Price: 32.0
# 66                     Purchase Price: 39.0
# 67                     Purchase Price: 28.0
#
# [68 rows x 16 columns]

# %%
# clean sizes
print(wines['size'].unique())

# replace 0,75 with 0.75
wines['size'] = wines['size'].apply(lambda x: re.sub(r'0,75', '0.75', x))

# replace MG with 1.5
wines['size'] = wines['size'].apply(lambda x: re.sub(r'MG', '1.5', x))

print(wines['size'].unique())
# Out:
# ['0,75' 'MG']
# ['0.75' '1.5']

# %%
wines.head()
# Out:
#     external_id type    name_one       name_two     Stato        Zona
# 0  8.767565e+10  NaN       ANJOU       EFFUSION   FRANCIA       LOIRA  \
# 1  8.796437e+10  NaN       ANJOU  LE CORNILLARD   FRANCIA       LOIRA
# 2  7.677869e+13  NaN      ARNEIS   ROERO ARNEIS  PIEMONTE       ROERO
# 3           NaN  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
# 4  8.033255e+12  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
#
#                     winery_name  vintage  size  price   cost  quantity
# 0      DOMAINE PATRICK BAUDOUIN   2021.0  0.75     55   25.5       3.0  \
# 1      DOMAINE PATRICK BAUDOUIN   2020.0  0.75     90   39.5       3.0
# 2             GIACOMO FENOCCHIO   2022.0  0.75     28   11.0      16.0
# 3  AZ FALLETTO DI BRUNO GIACOSA   2015.0  0.75    200  135.0       1.0
# 4                       CERETTO   2018.0   1.5    190   98.0       2.0
#
#                   name storage_area info         internal_notes
# 0       ANJOU EFFUSION                     Purchase Price: 25.5
# 1  ANJOU LE CORNILLARD                     Purchase Price: 39.5
# 2  ARNEIS ROERO ARNEIS                     Purchase Price: 11.0
# 3     BARBARESCO ASILI                    Purchase Price: 135.0
# 4     BARBARESCO ASILI                     Purchase Price: 98.0

# %% [markdown]
# ### This part is still CUSTOM but more or less it is needed for all onboardings - This is specific for EnoWeb

# %%
# drop duplicates
wines = wines.drop_duplicates()

print(f'Total rows: {wines.shape[0]}')
# Out:
# Total rows: 210

# %%
# Define the sizes-to-enum map
sizes = {
    '0.375': 'HALF_BOTTLE',
    '0.5': 'HALF_LITER',
    '0.75': 'BOTTLE',
    '1': 'LITER',
    '1.5': 'MAGNUM',
    '3': 'JEROBOAM',
    '4.5': 'REHOBOAM',
    '5': 'BORDEAUX_JEROBOAM',
    '6': 'MATHUSALEM',
    '9': 'SALMANAZAR',
    '12': 'BALTHAZAR',
    '15': 'NEBUCHADNEZZAR',
    '18': 'MELCHIOR',
    '20': 'SOLOMON',
    '25': 'SOVEREIGN',
    '27': 'GOLIATH',
    '30': 'MELCHIZEDEK'
}

wines['size'] = wines['size'].map(sizes)

wines.head()
# Out:
#     external_id type    name_one       name_two     Stato        Zona
# 0  8.767565e+10  NaN       ANJOU       EFFUSION   FRANCIA       LOIRA  \
# 1  8.796437e+10  NaN       ANJOU  LE CORNILLARD   FRANCIA       LOIRA
# 2  7.677869e+13  NaN      ARNEIS   ROERO ARNEIS  PIEMONTE       ROERO
# 3           NaN  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
# 4  8.033255e+12  RED  BARBARESCO          ASILI  PIEMONTE  BARBARESCO
#
#                     winery_name  vintage size  price   cost  quantity
# 0      DOMAINE PATRICK BAUDOUIN   2021.0  NaN     55   25.5       3.0  \
# 1      DOMAINE PATRICK BAUDOUIN   2020.0  NaN     90   39.5       3.0
# 2             GIACOMO FENOCCHIO   2022.0  NaN     28   11.0      16.0
# 3  AZ FALLETTO DI BRUNO GIACOSA   2015.0  NaN    200  135.0       1.0
# 4                       CERETTO   2018.0  NaN    190   98.0       2.0
#
#                   name storage_area info         internal_notes
# 0       ANJOU EFFUSION                     Purchase Price: 25.5
# 1  ANJOU LE CORNILLARD                     Purchase Price: 39.5
# 2  ARNEIS ROERO ARNEIS                     Purchase Price: 11.0
# 3     BARBARESCO ASILI                    Purchase Price: 135.0
# 4     BARBARESCO ASILI                     Purchase Price: 98.0

# %% [markdown]
# ### Save new version of the winelist

# %%
# drop columns that are not the required ones
# - `external_id`
# - `name`
# - `winery_name`
# - `type`
# - `storage_area`
# - `size`
# - `vintage`
# - `price`
# - `info`
# - `quantity`
# - `internal_notes`

wines = wines[['external_id', 'name', 'winery_name', 'type', 'storage_area', 'size', 'vintage', 'price', 'info', 'quantity', 'internal_notes']]

# %%
open('v2-cleaned.csv', 'w').close()

wines.to_csv('v2-cleaned.csv', index=False)

# %% [markdown]
# ### Print search terms
#
# **NOTE: Before proceeding with the matching algorithm, run the viviner and insert new wines.**

# %%
with open('search-terms.txt', 'w') as f:
    for term in wines['name'].unique():
        f.write(f'{term}\n')
    for term in wines['winery_name'].unique():
        f.write(f'{term}\n')
