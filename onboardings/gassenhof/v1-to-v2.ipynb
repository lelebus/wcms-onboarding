# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head()
# Out:
#        external_id                                       full_details   type  \
# 0   v.69999.2020.c  Abbazia di Novacella, Cor unum et anima una, 2...  WHITE
# 1   v.13842.2022.b  Abbazia di Novacella, Grüner Veltliner Praepos...  WHITE
# 2   v.13841.2023.b  Abbazia di Novacella, Kerner Praepositus, 2023...  WHITE
# 3    v.6142.2022.b  Abbazia di Novacella, Riesling Praepositus, 20...  WHITE
# 4  v.100767.2019.b      Acham-Magin, Riesling Ungeheuer, 2019, 750 ml  WHITE
#
#    purchase_price_eur sales_price_eur
# 0                 NaN          114.00
# 1                 NaN           35.00
# 2                 NaN           35.00
# 3                 NaN           37.00
# 4                 NaN           91.00

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
# copy values from original columns to new columns
df['external_id'] = df1['external_id']
df['type'] = df1['type']
df["quantity"] = 200
df["storage_area"] = None
df["info"] = None
df["internal_notes"] = None
df["visible"] = True

df.head()
# Out:
#        external_id   type name winery_name  info size vintage price  \
# 0   v.69999.2020.c  WHITE  NaN         NaN  None  NaN     NaN   NaN
# 1   v.13842.2022.b  WHITE  NaN         NaN  None  NaN     NaN   NaN
# 2   v.13841.2023.b  WHITE  NaN         NaN  None  NaN     NaN   NaN
# 3    v.6142.2022.b  WHITE  NaN         NaN  None  NaN     NaN   NaN
# 4  v.100767.2019.b  WHITE  NaN         NaN  None  NaN     NaN   NaN
#
#   purchase_price  quantity storage_area internal_notes  visible
# 0            NaN       200         None           None     True
# 1            NaN       200         None           None     True
# 2            NaN       200         None           None     True
# 3            NaN       200         None           None     True
# 4            NaN       200         None           None     True

# %%
def convert_price_to_cents(x):
    if pd.isna(x) or str(x).strip() == '':
        return 0
    try:
        return int(float(str(x).replace('€', '').replace(',', '').strip()) * 100)
    except (ValueError, TypeError):
        return 0

df1['sales_price_eur'] = df1['sales_price_eur'].fillna('')
df['price'] = df1['sales_price_eur'].apply(convert_price_to_cents)

df1['purchase_price_eur'] = df1['purchase_price_eur'].fillna('')
df['purchase_price'] = df1['purchase_price_eur'].apply(convert_price_to_cents)

df.head()
# Out:
#        external_id   type name winery_name  info size vintage  price  \
# 0   v.69999.2020.c  WHITE  NaN         NaN  None  NaN     NaN  11400
# 1   v.13842.2022.b  WHITE  NaN         NaN  None  NaN     NaN   3500
# 2   v.13841.2023.b  WHITE  NaN         NaN  None  NaN     NaN   3500
# 3    v.6142.2022.b  WHITE  NaN         NaN  None  NaN     NaN   3700
# 4  v.100767.2019.b  WHITE  NaN         NaN  None  NaN     NaN   9100
#
#    purchase_price  quantity storage_area internal_notes  visible
# 0               0       200         None           None     True
# 1               0       200         None           None     True
# 2               0       200         None           None     True
# 3               0       200         None           None     True
# 4               0       200         None           None     True

# %% [markdown]
# ### This part is specific for EnoWeb

# %%
# Define the sizes-to-enum map
sizes_map = {
    'a': 'HALF_BOTTLE',
    'm': 'HALF_LITER',
    'b': 'BOTTLE',
    'o': 'LITER',
    'c': 'MAGNUM',
    'u': 'MAGNUM',
    'd': 'JEROBOAM',
    4.5: 'REHOBOAM',
    'q': 'BORDEAUX_JEROBOAM',
    'f': 'MATHUSALEM',
    9: 'SALMANAZAR',
    12: 'BALTHAZAR',
    15: 'NEBUCHADNEZZAR',
    18: 'MELCHIOR',
    20: 'SOLOMON',
    25: 'SOVEREIGN',
    27: 'GOLIATH',
    30: 'MELCHIZEDEK'
}

# %%
# Enoweb structure, so exploit that to extract the other details
for idx, wine in df1.iterrows():
    # extract wine, winery name, and size from full_details
    full_details_tokens = wine['full_details'].split(',')
    df.at[idx, 'winery_name'] = full_details_tokens[0]
    df.at[idx, 'name'] = full_details_tokens[1]
    
    # extract vintage and size from external_id
    external_id_tokens = wine['external_id'].split('.')
    df.at[idx, 'vintage'] = external_id_tokens[2]
    df.at[idx, 'size'] = sizes_map[external_id_tokens[3]]

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#        external_id   type                           name  \
# 0   v.69999.2020.c  WHITE          Cor unum et anima una
# 1   v.13842.2022.b  WHITE   Grüner Veltliner Praepositus
# 2   v.13841.2023.b  WHITE             Kerner Praepositus
# 3    v.6142.2022.b  WHITE           Riesling Praepositus
# 4  v.100767.2019.b  WHITE             Riesling Ungeheuer
#
#             winery_name info    size  vintage  price  purchase_price  \
# 0  Abbazia di Novacella       MAGNUM     2020  11400               0
# 1  Abbazia di Novacella       BOTTLE     2022   3500               0
# 2  Abbazia di Novacella       BOTTLE     2023   3500               0
# 3  Abbazia di Novacella       BOTTLE     2022   3700               0
# 4           Acham-Magin       BOTTLE     2019   9100               0
#
#    quantity storage_area internal_notes  visible
# 0       200                                 True
# 1       200                                 True
# 2       200                                 True
# 3       200                                 True
# 4       200                                 True

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
