# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")

# %%
# Fill in prefix for rows where it's empty by using previous non-empty prefix
current_prefix = None
for idx, row in df1.iterrows():
    if pd.notna(row['prefix']) and row['prefix'] != '':
        current_prefix = row['prefix']
    else:
        df1.at[idx, 'prefix'] = current_prefix

# Drop rows where name is empty
df1 = df1.dropna(subset=['name'])
# Also drop rows where name is empty string
df1 = df1[df1['name'] != '']

# %%
# Rows to drop
# add rows where vintage is not 0 or a valid year (year can be a string or an int)
# Function to check if vintage is valid (0 or a valid year between 1900-2023)
def is_valid_vintage(vintage):
    try:
        # string to int first to handle both int and float inputs
        vintage = int(vintage)
        if vintage == 0:
            return True
        return 1900 <= vintage <= 2024
    except:
        return False

# Get rows where vintage is invalid
rows_to_drop = df1[~df1['vintage'].apply(is_valid_vintage)]

# store dropped rows in csv
rows_to_drop.to_csv("v2-dropped.csv", index=False)

# remove from df1
df1 = df1[df1['vintage'].apply(is_valid_vintage)]

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head()
# Out:
#   type          prefix                 name    winery internal_notes size  \
# 0  NaN  Metodo Charmat            Ruio Brut  Malibran            NaN  NaN
# 1  NaN  Metodo Charmat            Rose Brut  Malibran            NaN  NaN
# 2  NaN  Metodo Charmat  Col Fondo Sottoriva  Malibran            NaN  NaN
# 3  NaN  Metodo Charmat            Credamora  Malibran            NaN  NaN
# 4  NaN  Metodo Charmat    Col Fondo vintage  Malibran            NaN  NaN
#
#   vintage ricavo purchase_price   sales_price  qty
# 0       0     28         5.85 €      35.00 €   276
# 1       0     33         5.85 €      40.00 €    58
# 2       0     28         5.85 €      35.00 €    14
# 3    2021     36            7 €      45.00 €     7
# 4    2016      ö            0 €   NON IN LIST    3

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
import re

# copy values from original columns to new columns
df['external_id'] = None
df['type'] = df1['type']
df['name'] = df1['prefix'] + ' ' + df1['name']
df['winery_name'] = df1['winery']
# First extract vintage from name
df["vintage"] = df1["vintage"]
df["quantity"] = df1["qty"]
df["internal_notes"] = df1["internal_notes"]
df["visible"] = True

df.head()
# Out:
#   external_id type                                name winery_name info size  \
# 0         NaN  NaN            Metodo Charmat Ruio Brut    Malibran  NaN  NaN
# 1         NaN  NaN            Metodo Charmat Rose Brut    Malibran  NaN  NaN
# 2         NaN  NaN  Metodo Charmat Col Fondo Sottoriva    Malibran  NaN  NaN
# 3         NaN  NaN            Metodo Charmat Credamora    Malibran  NaN  NaN
# 4         NaN  NaN    Metodo Charmat Col Fondo vintage    Malibran  NaN  NaN
#
#   vintage price purchase_price quantity storage_area internal_notes  visible
# 0       0   NaN            NaN      276          NaN            NaN     True
# 1       0   NaN            NaN       58          NaN            NaN     True
# 2       0   NaN            NaN       14          NaN            NaN     True
# 3    2021   NaN            NaN        7          NaN            NaN     True
# 4    2016   NaN            NaN        3          NaN            NaN     True

# %%
# rows with sales_price  that contains 'NON IN LIST' should set visible to false and price to 0
non_list_mask = df1['sales_price'].str.contains('NON', case=False, na=False)
df1.loc[non_list_mask, 'visible'] = False
df1.loc[non_list_mask, 'sales_price'] = 0

# %%
# size
df['size'] = df1["size"].fillna("BOTTLE")

# fill empty prices with 0
df1['price_eur'] = df1['sales_price'].fillna(0)
df1['purchase_price_eur'] = df1['purchase_price'].fillna(0)

# convert prices to cents
df['price'] = df1['price_eur'].apply(lambda x: int(float(str(x).replace('€', ''))*100)) # convert to cents
df['purchase_price'] = df1['purchase_price_eur'].apply(lambda x: int(float(str(x).replace('€', ''))*100)) # convert to cents

df.head()
# Out:
#   external_id type                                name winery_name info  \
# 0         NaN  NaN            Metodo Charmat Ruio Brut    Malibran  NaN
# 1         NaN  NaN            Metodo Charmat Rose Brut    Malibran  NaN
# 2         NaN  NaN  Metodo Charmat Col Fondo Sottoriva    Malibran  NaN
# 3         NaN  NaN            Metodo Charmat Credamora    Malibran  NaN
# 4         NaN  NaN    Metodo Charmat Col Fondo vintage    Malibran  NaN
#
#      size vintage  price  purchase_price quantity storage_area internal_notes  \
# 0  BOTTLE       0   3500             585      276          NaN            NaN
# 1  BOTTLE       0   4000             585       58          NaN            NaN
# 2  BOTTLE       0   3500             585       14          NaN            NaN
# 3  BOTTLE    2021   4500             700        7          NaN            NaN
# 4  BOTTLE    2016      0               0        3          NaN            NaN
#
#    visible
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id type                                name winery_name info  \
# 0                             Metodo Charmat Ruio Brut    Malibran
# 1                             Metodo Charmat Rose Brut    Malibran
# 2                   Metodo Charmat Col Fondo Sottoriva    Malibran
# 3                             Metodo Charmat Credamora    Malibran
# 4                     Metodo Charmat Col Fondo vintage    Malibran
#
#      size  vintage  price  purchase_price  quantity storage_area  \
# 0  BOTTLE        0   3500             585       276
# 1  BOTTLE        0   4000             585        58
# 2  BOTTLE        0   3500             585        14
# 3  BOTTLE     2021   4500             700         7
# 4  BOTTLE     2016      0               0         3
#
#   internal_notes  visible
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
