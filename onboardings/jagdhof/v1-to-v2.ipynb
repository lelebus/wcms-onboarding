# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")

# %%
# Function to split vintage ranges and create new rows
def split_vintage_range(row):
    if isinstance(row['vintage'], str) and '/' in row['vintage']:
        # Get the two vintages
        vintage1, vintage2 = row['vintage'].split('/')

        if vintage1 == vintage2:
            return [row]
        
        # Create two rows with different vintages
        row1 = row.copy()
        row2 = row.copy()
        
        row1['vintage'] = vintage1
        row2['vintage'] = vintage2
        
        return [row1, row2]
    return [row]

# Apply the splitting function and explode the dataframe
df_expanded = pd.DataFrame([
    new_row for _, row in df1.iterrows() 
    for new_row in split_vintage_range(row)
])

# Reset index after expansion
df_expanded = df_expanded.reset_index(drop=True)

df1 = df_expanded

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head(8)
# Out:
#                                  name              winery vintage  size  \
# 0          Piris Prosecco (Extra Dry)           Sacchetto       /  0.75
# 1  Spumante „Bella Glamour Zero Zero“        Iris Vigneti       /  0.75
# 2              Sekt Brut „Praeclarus“  Kellerei St. Pauls       /  0.75
# 3                      Sekt Brut Rosé   Arunda - Reiterer       /  0.75
# 4             Sekt Extra Brut Riserva   Arunda - Reiterer       /  0.75
# 5               Brut Riserva Methius             Dorigati    2015  0.75
# 6               Brut Riserva Methius             Dorigati    2016  0.75
# 7              Prosecco Brut Rosé Bio            Corvezzo       /  0.75
#
#   sales_price_eur purchase_price storage_area
# 0         € 39.00         € 4.22   Hauptlager
# 1         € 31.00         € 5.50   Hauptlager
# 2         € 46.00        € 14.90   Hauptlager
# 3         € 53.00        € 20.50   Hauptlager
# 4         € 59.00        € 22.50   Hauptlager
# 5         € 69.00        € 27.80   Hauptlager
# 6         € 69.00        € 27.80   Hauptlager
# 7         € 38.00         € 5.95   Hauptlager

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
import re

# copy values from original columns to new columns
df['external_id'] = None
df['type'] = None
df['name'] = df1['name']
df['winery_name'] = df1['winery']
# First extract vintage from name
df["vintage"] = df1["vintage"].apply(lambda x: int(re.search(r'\d{4}', x).group()) if re.search(r'\d{4}', x) else 0 if x == '/' else None)
df["name"] = df1["name"]
df["quantity"] = 50
df["storage_area"] = df1["storage_area"]
df["visible"] = True

df.head()
# Out:
#   external_id type                                name         winery_name  \
# 0         NaN  NaN          Piris Prosecco (Extra Dry)           Sacchetto
# 1         NaN  NaN  Spumante „Bella Glamour Zero Zero“        Iris Vigneti
# 2         NaN  NaN              Sekt Brut „Praeclarus“  Kellerei St. Pauls
# 3         NaN  NaN                      Sekt Brut Rosé   Arunda - Reiterer
# 4         NaN  NaN             Sekt Extra Brut Riserva   Arunda - Reiterer
#
#   info size  vintage price purchase_price  quantity storage_area  \
# 0  NaN  NaN        0   NaN            NaN        50   Hauptlager
# 1  NaN  NaN        0   NaN            NaN        50   Hauptlager
# 2  NaN  NaN        0   NaN            NaN        50   Hauptlager
# 3  NaN  NaN        0   NaN            NaN        50   Hauptlager
# 4  NaN  NaN        0   NaN            NaN        50   Hauptlager
#
#   internal_notes  visible
# 0            NaN     True
# 1            NaN     True
# 2            NaN     True
# 3            NaN     True
# 4            NaN     True

# %%
# sizes
SIZE_MAPPING = {
    0.75: "BOTTLE",
    1.5: "MAGNUM",
    3.0: "JEROBOAM",
    0.5: "HALF_BOTTLE"
}

df['size'] = df1["size"].map(SIZE_MAPPING).fillna("BOTTLE")

# print unique sizes
print(df['size'].unique())
# Out:
# ['BOTTLE' 'MAGNUM' 'JEROBOAM' 'HALF_BOTTLE']

# %%
# fill empty prices with 0
df1['price_eur'] = df1['sales_price_eur'].fillna(0)
df1['purchase_price_eur'] = df1['purchase_price'].fillna(0)

# convert prices to cents
df['price'] = df1['price_eur'].apply(lambda x: int(float(x.replace('€', ''))*100)) # convert to cents
df['purchase_price'] = df1['purchase_price_eur'].apply(lambda x: int(float(x.replace('€', ''))*100)) # convert to cents

df.head()
# Out:
#   external_id type                                name         winery_name  \
# 0         NaN  NaN          Piris Prosecco (Extra Dry)           Sacchetto
# 1         NaN  NaN  Spumante „Bella Glamour Zero Zero“        Iris Vigneti
# 2         NaN  NaN              Sekt Brut „Praeclarus“  Kellerei St. Pauls
# 3         NaN  NaN                      Sekt Brut Rosé   Arunda - Reiterer
# 4         NaN  NaN             Sekt Extra Brut Riserva   Arunda - Reiterer
#
#   info    size  vintage  price  purchase_price  quantity storage_area  \
# 0  NaN  BOTTLE        0   3900             422        50   Hauptlager
# 1  NaN  BOTTLE        0   3100             550        50   Hauptlager
# 2  NaN  BOTTLE        0   4600            1490        50   Hauptlager
# 3  NaN  BOTTLE        0   5300            2050        50   Hauptlager
# 4  NaN  BOTTLE        0   5900            2250        50   Hauptlager
#
#   internal_notes  visible
# 0            NaN     True
# 1            NaN     True
# 2            NaN     True
# 3            NaN     True
# 4            NaN     True

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id type                                name         winery_name  \
# 0                           Piris Prosecco (Extra Dry)           Sacchetto
# 1                   Spumante „Bella Glamour Zero Zero“        Iris Vigneti
# 2                               Sekt Brut „Praeclarus“  Kellerei St. Pauls
# 3                                       Sekt Brut Rosé   Arunda - Reiterer
# 4                              Sekt Extra Brut Riserva   Arunda - Reiterer
#
#   info    size  vintage  price  purchase_price  quantity storage_area  \
# 0       BOTTLE        0   3900             422        50   Hauptlager
# 1       BOTTLE        0   3100             550        50   Hauptlager
# 2       BOTTLE        0   4600            1490        50   Hauptlager
# 3       BOTTLE        0   5300            2050        50   Hauptlager
# 4       BOTTLE        0   5900            2250        50   Hauptlager
#
#   internal_notes  visible
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
