# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")

# %%
# Function to split vintage ranges and create new rows
def split_vintage_range(row):
    if isinstance(row['vintage'], str) and '/' in row['vintage']:
        # Get the two vintages
        vintage1, vintage2 = row['vintage'].split('/')

        if vintage1 == vintage2:
            return [row]
        
        # Create two rows with different vintages
        row1 = row.copy()
        row2 = row.copy()
        
        row1['vintage'] = vintage1
        row2['vintage'] = vintage2
        
        return [row1, row2]
    return [row]

# Apply the splitting function and explode the dataframe
df_expanded = pd.DataFrame([
    new_row for _, row in df1.iterrows() 
    for new_row in split_vintage_range(row)
])

# Reset index after expansion
df_expanded = df_expanded.reset_index(drop=True)

df1 = df_expanded

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head(8)
# Out:
#                                  name              winery vintage  size  \
# 0          Piris Prosecco (Extra Dry)           Sacchetto       /  0.75
# 1  Spumante „Bella Glamour Zero Zero“        Iris Vigneti       /  0.75
# 2              Sekt Brut „Praeclarus“  Kellerei St. Pauls       /  0.75
# 3                      Sekt Brut Rosé   Arunda - Reiterer       /  0.75
# 4             Sekt Extra Brut Riserva   Arunda - Reiterer       /  0.75
# 5               Brut Riserva Methius             Dorigati    2015  0.75
# 6               Brut Riserva Methius             Dorigati    2016  0.75
# 7              Prosecco Brut Rosé Bio            Corvezzo       /  0.75
#
#   sales_price_eur purchase_price storage_area
# 0         € 39.00         € 4.22   Hauptlager
# 1         € 31.00         € 5.50   Hauptlager
# 2         € 46.00        € 14.90   Hauptlager
# 3         € 53.00        € 20.50   Hauptlager
# 4         € 59.00        € 22.50   Hauptlager
# 5         € 69.00        € 27.80   Hauptlager
# 6         € 69.00        € 27.80   Hauptlager
# 7         € 38.00         € 5.95   Hauptlager

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
import re

# copy values from original columns to new columns
df['external_id'] = None
df['type'] = None
df['name'] = df1['name']
df['winery_name'] = df1['winery']
# First extract vintage from name
df["vintage"] = df1["vintage"].apply(lambda x: int(re.search(r'\d{4}', x).group()) if re.search(r'\d{4}', x) else 0 if x == '/' else None)
df["name"] = df1["name"]
df["quantity"] = 0
df["storage_area"] = df1["storage_area"]
df["visible"] = True

df.head()
# Out:
#   external_id       type                                          name  \
# 1        None  SPARKLING                Champagne Venus Brut Grand Cru
# 2        None  SPARKLING       Champagne Avizoise Extra Brut Granc Cru
# 3        None  SPARKLING       Champagne Terroirs Extra Brut Grand Cru
# 4        None  SPARKLING                   Champagne 7 Crus Extra Brut
# 5        None  SPARKLING  Champagne Mineral Extra Brut Blanc de Blancs
#
#   winery_name info size  vintage price purchase_price  quantity storage_area  \
# 1    AGRAPART  NaN  NaN   2017.0   NaN            NaN         0          NaN
# 2    AGRAPART  NaN  NaN      NaN   NaN            NaN         0          NaN
# 3    AGRAPART  NaN  NaN      NaN   NaN            NaN         0          NaN
# 4    AGRAPART  NaN  NaN      NaN   NaN            NaN         0          NaN
# 5    AGRAPART  NaN  NaN      NaN   NaN            NaN         0          NaN
#
#                    internal_notes  visible
# 1                 Chardonnay 100%     True
# 2                 Chardonnay 100%     True
# 3                 Chardonnay 100%     True
# 4  Chardonnay 90%, Pinot Noir 10%     True
# 5                 Chardonnay 100%     True

# %%
# size
df['size'] = df1["size"].fillna("BOTTLE")

# convert prices to cents
df['price'] = df1['eur_price']
# fill empty prices with 0
df1['eur_price'] = df1['eur_price'].fillna(0)

# convert prices to cents
df['price'] = df1['eur_price'].apply(lambda x: int(float(x)*100)) # convert to cents

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 10
#       7 df1['sales_price'] = df1['eur_price'].fillna(0)
#       9 # convert prices to cents
# ---> 10 df['price'] = df1['eur_price'].apply(lambda x: int(float(x)*100)) # convert to cents
#      12 df.head()
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[16], line 10, in <lambda>(x)
#       7 df1['sales_price'] = df1['eur_price'].fillna(0)
#       9 # convert prices to cents
# ---> 10 df['price'] = df1['eur_price'].apply(lambda x: int(float(x)*100)) # convert to cents
#      12 df.head()
#
# ValueError: cannot convert float NaN to integer

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id       type                                   name   winery_name  \
# 0     10110.0  SPARKLING  Prosecco di Valdobbiadene, Extra Brut      Bortolin
# 1     10116.0  SPARKLING              Arunda Brut Rosè Exellor         Arunda
# 2     10117.0  SPARKLING               Hausmannhof Reserve 2013     Haderburg
# 3     10118.0  SPARKLING                      Solera Extra Brut  Marco Buvoli
# 4     10119.0  SPARKLING                Haderburg Spumante Brut     Haderburg
#
#   info    size  vintage  price  purchase_price  quantity storage_area  \
# 0       BOTTLE        0   3500             800        50
# 1       BOTTLE        0   5400            2500        50
# 2       BOTTLE     2013   6900            3500        50
# 3       BOTTLE        0   7500            2900        50
# 4       BOTTLE        0   3900            1600        50
#
#   internal_notes  visible  takeaway_price
# 0         Holzer     True            1300
# 1        Karadar     True            3950
# 2         direkt     True            5550
# 3                    True            4600
# 4         direkt     True            2860

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
