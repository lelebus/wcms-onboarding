# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")
df1.head()
# Out:
#                 name            winery  vintage    size  qty  purchase_price  \
# 0      ROSSO RISERVA  BORGO DEL TIGLIO   1999.0  BOTTLE  6.0             NaN
# 1  ROSSO DELLA CENTA  BORGO DEL TIGLIO   2001.0  BOTTLE  1.0             NaN
# 2          SAUVIGNON  BORGO DEL TIGLIO   2009.0  BOTTLE  2.0             NaN
# 3           VERDUZZO  BORGO DEL TIGLIO   1998.0  BOTTLE  5.0             NaN
# 4           MALVASIA  BORGO DEL TIGLIO   2022.0  BOTTLE  4.0             NaN
#
#   internal_notes internal_notes_2
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head()
# Out:
#                 name            winery  vintage    size  qty  purchase_price  \
# 0      ROSSO RISERVA  BORGO DEL TIGLIO   1999.0  BOTTLE  6.0             NaN
# 1  ROSSO DELLA CENTA  BORGO DEL TIGLIO   2001.0  BOTTLE  1.0             NaN
# 2          SAUVIGNON  BORGO DEL TIGLIO   2009.0  BOTTLE  2.0             NaN
# 3           VERDUZZO  BORGO DEL TIGLIO   1998.0  BOTTLE  5.0             NaN
# 4           MALVASIA  BORGO DEL TIGLIO   2022.0  BOTTLE  4.0             NaN
#
#   internal_notes internal_notes_2
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
# copy values from original columns to new columns
df['name'] = df1['name']

# remove content within brackets
df['winery_name'] = df1['winery'].apply(lambda x: x.split("(")[0].strip())

df["vintage"] = df1["vintage"]
df["quantity"] = df1["qty"]
df["size"] = df1["size"]
df["storage_area"] = "Cantinetta"

# append another columns value
df["internal_notes"] = df1['internal_notes'].fillna("") + " " + df1['internal_notes_2'].fillna("")
df["visible"] = True

df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       2 df['name'] = df1['name']
#       4 # remove content within brackets
# ----> 5 df['winery_name'] = df1['winery'].apply(lambda x: x.split("(")[0].strip())
#       7 df["vintage"] = df1["vintage"]
#       8 df["quantity"] = df1["qty"]
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Documents/vinoteqa/clients/onboarding/venv/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[15], line 5, in <lambda>(x)
#       2 df['name'] = df1['name']
#       4 # remove content within brackets
# ----> 5 df['winery_name'] = df1['winery'].apply(lambda x: x.split("(")[0].strip())
#       7 df["vintage"] = df1["vintage"]
#       8 df["quantity"] = df1["qty"]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# size
df['size'] = df1["size"].fillna("BOTTLE")

# convert prices to cents
df['price'] = 0
df['purchase_price'] = df1['purchase_price'].apply(lambda x: int(x*100) if not pd.isnull(x) else 0) # convert to cents

df.tail()
# Out:
#     external_id type                               name          winery_name  \
# 180         NaN  NaN              RICHEBOURG GRAND CRU   DOMAINE JEAN GRIVOT
# 181         NaN  NaN               CHAMBERTIN GRAND CRU       DOMAINE TRAPES
# 182         NaN  NaN  LATRICIERES CHAMBERTIN GRAND CRU        DOMAINE TRAPES
# 183         NaN  NaN             GEVREY CHAMBERTIN 1CRU       DOMAINE TRAPES
# 184         NaN  NaN                            POMEROL        CHATEAU GAZIN
#
#     info    size  vintage  price  purchase_price  quantity storage_area  \
# 180  NaN  BOTTLE     2004      0               0         2   Cantinetta
# 181  NaN  BOTTLE     2006      0               0         2   Cantinetta
# 182  NaN  BOTTLE     2006      0               0         2   Cantinetta
# 183  NaN  BOTTLE     2006      0               0         2   Cantinetta
# 184  NaN  BOTTLE     2019      0           10200         2   Cantinetta
#
#       internal_notes  visible
# 180                      True
# 181                      True
# 182                      True
# 183                      True
# 184  Pagata io 102€      True

# %%
df = fill_empty(df, VColumns.v2())
df.tail()
# Out:
#     external_id type                               name          winery_name  \
# 180                               RICHEBOURG GRAND CRU   DOMAINE JEAN GRIVOT
# 181                                CHAMBERTIN GRAND CRU       DOMAINE TRAPES
# 182                   LATRICIERES CHAMBERTIN GRAND CRU        DOMAINE TRAPES
# 183                              GEVREY CHAMBERTIN 1CRU       DOMAINE TRAPES
# 184                                             POMEROL        CHATEAU GAZIN
#
#     info    size  vintage  price  purchase_price  quantity storage_area  \
# 180       BOTTLE     2004      0               0         2   Cantinetta
# 181       BOTTLE     2006      0               0         2   Cantinetta
# 182       BOTTLE     2006      0               0         2   Cantinetta
# 183       BOTTLE     2006      0               0         2   Cantinetta
# 184       BOTTLE     2019      0           10200         2   Cantinetta
#
#       internal_notes  visible
# 180                      True
# 181                      True
# 182                      True
# 183                      True
# 184  Pagata io 102€      True

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
