# %% [markdown]
# # Prepare wines from a dirty list
#
# Load a CSV of wines (aka winelist) and clean the data to get it ready to run it through the matching algorithm.

# %%
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load dirty winelist file and perform cleaning

# %%
original_wines = pd.read_csv('v1-cleaned.csv')
print(f'Total rows: {original_wines.shape[0]}')
print()

original_wines.head()
# Out:
# Total rows: 472
#    external_id    size                             name
# 0          1.0  BOTTLE                         Le Petit  \
# 1          2.0  BOTTLE  Gewürztraminer Passito "Cresta"
# 2          3.0  BOTTLE           Rosenmuskateller Rosis
# 3          4.0  BOTTLE                    Sweet Claire
# 4          5.0  BOTTLE         Sweet Claire Quintessenz
#
#                   winery_name  vintage supplier purchase_price       price
# 0            Weingut Manincor   2018.0       WD       37.40 €     80.00 €   \
# 1  Weingut Hans Rottensteiner   2017.0       WD       20.90 €     57.00 €
# 2              Kellerei Bozen   2020.0       FW       18.00 €     53.00 €
# 3          Weingut Lieselehof   2017.0  Liesele       39.90 €     77.00 €
# 4          Weingut Lieselehof   2015.0  Liesele       94.73 €    199.00 €
#
#   retail_price glass_price  quantity
# 0     75.29 €     € 13.33          6
# 1     42.07 €      € 9.50          9
# 2     36.23 €      € 8.83          9
# 3     80.32 €     € 12.83          5
# 4    190.69 €     € 33.17          2

# %% [markdown]
# We need the following fields:
#
# - `external_id`
# - `name`
# - `winery_name`
# - `type`
# - `storage_area`
# - `size`
# - `vintage`
# - `price`
# - `info`
# - `quantity`
# - `internal_notes`
#
# ---

# %% [markdown]
# ### Note: This part is always CUSTOM to the client

# %% [markdown]
# - external_id OK
# - type missing
# - name OK
# - winery_name OK
# - storage_area missing
# - size OK
# - vintage drop if not a number or is 0
# - price -> remove currency symbol and transform to cents
# - quantity OK
# - info missing
# - internal_notes -> create from purchase_price, supplier, retail_price, glass_price

# %%
import math

# create a copy from original wines to avoid modifying data when rerunning this cell
wines = original_wines.copy()

# add empty type
wines['type'] = ''

# add empty storage_area
wines['storage_area'] = ''

# set 0 vintage year to None and NaN vintage year to None
wines['vintage'] = wines['vintage'].apply(lambda x: None if pd.isnull(x) or pd.isna(x) else int(x))

# set price
wines['price'] = wines['price'].apply(lambda x: x.replace('€', '') if pd.notnull(x) else None)
wines['price'] = wines['price'].apply(lambda x: float(x) * 100 if pd.notnull(x) else None)

# add empty info
wines['info'] = ''

# create internal_notes, aggregating purchase_price, supplier, retail_price, glass_price
wines['internal_notes'] = wines.apply(lambda x: f'purchase_price: {x["purchase_price"]}, supplier: {x["supplier"]}, retail_price: {x["retail_price"]}, glass_price: {x["glass_price"]}', axis=1)

wines.head()
# Out:
#    external_id    size                             name
# 0          1.0  BOTTLE                         Le Petit  \
# 1          2.0  BOTTLE  Gewürztraminer Passito "Cresta"
# 2          3.0  BOTTLE           Rosenmuskateller Rosis
# 3          4.0  BOTTLE                    Sweet Claire
# 4          5.0  BOTTLE         Sweet Claire Quintessenz
#
#                   winery_name  vintage supplier purchase_price    price
# 0            Weingut Manincor   2018.0       WD       37.40 €    8000.0  \
# 1  Weingut Hans Rottensteiner   2017.0       WD       20.90 €    5700.0
# 2              Kellerei Bozen   2020.0       FW       18.00 €    5300.0
# 3          Weingut Lieselehof   2017.0  Liesele       39.90 €    7700.0
# 4          Weingut Lieselehof   2015.0  Liesele       94.73 €   19900.0
#
#   retail_price glass_price  quantity type storage_area info
# 0     75.29 €     € 13.33          6                         \
# 1     42.07 €      € 9.50          9
# 2     36.23 €      € 8.83          9
# 3     80.32 €     € 12.83          5
# 4    190.69 €     € 33.17          2
#
#                                       internal_notes
# 0  purchase_price:  37.40 € , supplier: WD, retai...
# 1  purchase_price:  20.90 € , supplier: WD, retai...
# 2  purchase_price:  18.00 € , supplier: FW, retai...
# 3  purchase_price:  39.90 € , supplier: Liesele, ...
# 4  purchase_price:  94.73 € , supplier: Liesele, ...

# %%
# clean sizes

# set size to BOTTLE if empty
wines['size'] = wines['size'].apply(lambda x: 'BOTTLE' if pd.isnull(x) or pd.isna(x) else x)

print(wines['size'].unique())
# Out:
# ['BOTTLE' 'MAGNUM']

# %%
wines.head()
# Out:
#    external_id    size                             name
# 0          1.0  BOTTLE                         Le Petit  \
# 1          2.0  BOTTLE  Gewürztraminer Passito "Cresta"
# 2          3.0  BOTTLE           Rosenmuskateller Rosis
# 3          4.0  BOTTLE                    Sweet Claire
# 4          5.0  BOTTLE         Sweet Claire Quintessenz
#
#                   winery_name  vintage supplier purchase_price    price
# 0            Weingut Manincor   2018.0       WD       37.40 €    8000.0  \
# 1  Weingut Hans Rottensteiner   2017.0       WD       20.90 €    5700.0
# 2              Kellerei Bozen   2020.0       FW       18.00 €    5300.0
# 3          Weingut Lieselehof   2017.0  Liesele       39.90 €    7700.0
# 4          Weingut Lieselehof   2015.0  Liesele       94.73 €   19900.0
#
#   retail_price glass_price  quantity type storage_area info
# 0     75.29 €     € 13.33          6                         \
# 1     42.07 €      € 9.50          9
# 2     36.23 €      € 8.83          9
# 3     80.32 €     € 12.83          5
# 4    190.69 €     € 33.17          2
#
#                                       internal_notes
# 0  purchase_price:  37.40 € , supplier: WD, retai...
# 1  purchase_price:  20.90 € , supplier: WD, retai...
# 2  purchase_price:  18.00 € , supplier: FW, retai...
# 3  purchase_price:  39.90 € , supplier: Liesele, ...
# 4  purchase_price:  94.73 € , supplier: Liesele, ...

# %% [markdown]
# ### This part is still CUSTOM but more or less it is needed for all onboardings - This is specific for EnoWeb

# %%
# drop duplicates
wines = wines.drop_duplicates()

print(f'Total rows: {wines.shape[0]}')
# Out:
# Total rows: 472

# %%
# Define the sizes-to-enum map
sizes = {
    '0.375': 'HALF_BOTTLE',
    '0.5': 'HALF_LITER',
    '0.75': 'BOTTLE',
    '1': 'LITER',
    '1.5': 'MAGNUM',
    '3': 'JEROBOAM',
    '4.5': 'REHOBOAM',
    '5': 'BORDEAUX_JEROBOAM',
    '6': 'MATHUSALEM',
    '9': 'SALMANAZAR',
    '12': 'BALTHAZAR',
    '15': 'NEBUCHADNEZZAR',
    '18': 'MELCHIOR',
    '20': 'SOLOMON',
    '25': 'SOVEREIGN',
    '27': 'GOLIATH',
    '30': 'MELCHIZEDEK'
}

# skip this cuz we already mapped
# wines['size'] = wines['size'].map(sizes)

wines.head()
# Out:
#    external_id    size                             name
# 0          1.0  BOTTLE                         Le Petit  \
# 1          2.0  BOTTLE  Gewürztraminer Passito "Cresta"
# 2          3.0  BOTTLE           Rosenmuskateller Rosis
# 3          4.0  BOTTLE                    Sweet Claire
# 4          5.0  BOTTLE         Sweet Claire Quintessenz
#
#                   winery_name  vintage supplier purchase_price    price
# 0            Weingut Manincor   2018.0       WD       37.40 €    8000.0  \
# 1  Weingut Hans Rottensteiner   2017.0       WD       20.90 €    5700.0
# 2              Kellerei Bozen   2020.0       FW       18.00 €    5300.0
# 3          Weingut Lieselehof   2017.0  Liesele       39.90 €    7700.0
# 4          Weingut Lieselehof   2015.0  Liesele       94.73 €   19900.0
#
#   retail_price glass_price  quantity type storage_area info
# 0     75.29 €     € 13.33          6                         \
# 1     42.07 €      € 9.50          9
# 2     36.23 €      € 8.83          9
# 3     80.32 €     € 12.83          5
# 4    190.69 €     € 33.17          2
#
#                                       internal_notes
# 0  purchase_price:  37.40 € , supplier: WD, retai...
# 1  purchase_price:  20.90 € , supplier: WD, retai...
# 2  purchase_price:  18.00 € , supplier: FW, retai...
# 3  purchase_price:  39.90 € , supplier: Liesele, ...
# 4  purchase_price:  94.73 € , supplier: Liesele, ...

# %% [markdown]
# ### Save new version of the winelist

# %%
# drop columns that are not the required ones
# - `external_id`
# - `name`
# - `winery_name`
# - `type`
# - `storage_area`
# - `size`
# - `vintage`
# - `price`
# - `info`
# - `quantity`
# - `internal_notes`

wines = wines[['external_id', 'name', 'winery_name', 'type', 'storage_area', 'size', 'vintage', 'price', 'info', 'quantity', 'internal_notes']]

# %%
open('v2-cleaned.csv', 'w').close()

wines.to_csv('v2-cleaned.csv', index=False)

# %% [markdown]
# ### Print search terms
#
# **NOTE: Before proceeding with the matching algorithm, run the viviner and insert new wines.**

# %%
with open('search-terms.txt', 'w') as f:
    for term in wines['name'].unique():
        f.write(f'{term}\n')
    for term in wines['winery_name'].unique():
        f.write(f'{term}\n')
