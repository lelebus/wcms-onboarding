# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head()
# Out:
#   type                            name      size vintage      winery    qty  \
# 0  NaN         Prosecco DOCG Extra Dry       NaN     NaN  La Tordera  156.0
# 1  NaN        (Prosecco Valdobbiadene)       NaN     NaN         NaN    NaN
# 2  NaN  Prosecco DOCG Extra Dry Magnum       NaN     NaN  La Tordera   13.0
# 3  NaN        (Prosecco Valdobbiadene)       NaN     NaN         NaN    NaN
# 4  NaN     Prosecco DOCG Extra Dry  3L  JEROBOAM     NaN  La Tordera    3.0
#
#   purchase_price_eur  sales_price_eur
# 0            6.96 €              28.0
# 1                NaN              NaN
# 2           15.50 €              58.0
# 3                NaN              NaN
# 4           49.95 €             120.0

# %%
# print to file df1 where qty and purchase_price_eur are empty
df1[df1['qty'].isna() | df1['purchase_price_eur'].isna()].to_csv("v5-insert-manual.csv", index=False)

# %%
# drop rows where qty and eur_price are empty
df1 = df1[df1['qty'].notna() & df1['purchase_price_eur'].notna()]
df1.head()
# Out:
#   type                                         name      size vintage  \
# 0  NaN                      Prosecco DOCG Extra Dry       NaN     NaN
# 2  NaN               Prosecco DOCG Extra Dry Magnum       NaN     NaN
# 4  NaN                  Prosecco DOCG Extra Dry  3L  JEROBOAM     NaN
# 6  NaN              Lamm 12 Extra Brut - Südt. Sekt       NaN     NaN
# 7  NaN  Haderburg Pas Dosè Millesimato – Südt. Sekt       NaN     NaN
#
#                    winery    qty purchase_price_eur  sales_price_eur
# 0              La Tordera  156.0            6.96 €              28.0
# 2              La Tordera   13.0           15.50 €              58.0
# 4              La Tordera    3.0           49.95 €             120.0
# 6  Winkler Sektmanifaktur   15.0           28.50 €              54.0
# 7               Haderburg    3.0           25.50 €              62.0

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes, visible]
# Index: []

# %%
import re

# copy values from original columns to new columns
df['external_id'] = None
df['type'] = df1['type']
df['name'] = df1['name']
df['winery_name'] = df1['winery']
df["vintage"] = df1["vintage"]
df["quantity"] = df1["qty"]
df["storage_area"] = None
df["internal_notes"] = None
df["visible"] = True

df.head()
# Out:
#   external_id type                                         name  \
# 0         NaN  NaN                      Prosecco DOCG Extra Dry
# 2         NaN  NaN               Prosecco DOCG Extra Dry Magnum
# 4         NaN  NaN                  Prosecco DOCG Extra Dry  3L
# 6         NaN  NaN              Lamm 12 Extra Brut - Südt. Sekt
# 7         NaN  NaN  Haderburg Pas Dosè Millesimato – Südt. Sekt
#
#               winery_name info size vintage price purchase_price  quantity  \
# 0              La Tordera  NaN  NaN     NaN   NaN            NaN     156.0
# 2              La Tordera  NaN  NaN     NaN   NaN            NaN      13.0
# 4              La Tordera  NaN  NaN     NaN   NaN            NaN       3.0
# 6  Winkler Sektmanifaktur  NaN  NaN     NaN   NaN            NaN      15.0
# 7               Haderburg  NaN  NaN     NaN   NaN            NaN       3.0
#
#   storage_area internal_notes  visible
# 0         None           None     True
# 2         None           None     True
# 4         None           None     True
# 6         None           None     True
# 7         None           None     True

# %%
# size
df['size'] = df1["size"].fillna("BOTTLE")

# fill empty prices with 0
df1['sales_price_eur'] = df1['sales_price_eur'].fillna(0)
df1['purchase_price_eur'] = df1['purchase_price_eur'].fillna(0)

# convert prices to cents
df['price'] = df1['sales_price_eur'].apply(lambda x: int(float(str(x).replace('€', ''))*100)) # convert to cents
df['purchase_price'] = df1['purchase_price_eur'].apply(lambda x: int(float(str(x).replace('€', ''))*100)) # convert to cents

df.head()
# Out:
#   external_id type                                         name  \
# 0         NaN  NaN                      Prosecco DOCG Extra Dry
# 2         NaN  NaN               Prosecco DOCG Extra Dry Magnum
# 4         NaN  NaN                  Prosecco DOCG Extra Dry  3L
# 6         NaN  NaN              Lamm 12 Extra Brut - Südt. Sekt
# 7         NaN  NaN  Haderburg Pas Dosè Millesimato – Südt. Sekt
#
#               winery_name info      size vintage  price  purchase_price  \
# 0              La Tordera  NaN    BOTTLE     NaN   2800             696
# 2              La Tordera  NaN    BOTTLE     NaN   5800            1550
# 4              La Tordera  NaN  JEROBOAM     NaN  12000            4995
# 6  Winkler Sektmanifaktur  NaN    BOTTLE     NaN   5400            2850
# 7               Haderburg  NaN    BOTTLE     NaN   6200            2550
#
#    quantity storage_area internal_notes  visible
# 0     156.0         None           None     True
# 2      13.0         None           None     True
# 4       3.0         None           None     True
# 6      15.0         None           None     True
# 7       3.0         None           None     True

# %%
# print to file df1 where quantity <= 0
df[df['quantity'] <= 0].to_csv("v1-manual-insert-qty.csv", index=False)

# %%
# discard rows with 0 qty
df = df[df["quantity"] > 0]

df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id type                                         name  \
# 0                                       Prosecco DOCG Extra Dry
# 2                                Prosecco DOCG Extra Dry Magnum
# 4                                   Prosecco DOCG Extra Dry  3L
# 6                               Lamm 12 Extra Brut - Südt. Sekt
# 7                   Haderburg Pas Dosè Millesimato – Südt. Sekt
#
#               winery_name info      size  vintage  price  purchase_price  \
# 0              La Tordera         BOTTLE        0   2800             696
# 2              La Tordera         BOTTLE        0   5800            1550
# 4              La Tordera       JEROBOAM        0  12000            4995
# 6  Winkler Sektmanifaktur         BOTTLE        0   5400            2850
# 7               Haderburg         BOTTLE        0   6200            2550
#
#    quantity storage_area internal_notes  visible
# 0       156                                 True
# 2        13                                 True
# 4         3                                 True
# 6        15                                 True
# 7         3                                 True

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
# Out:
# False
