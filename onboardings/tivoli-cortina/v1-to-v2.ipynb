# %% [markdown]
# ## Parse txt file

# %%
years = {str(i) for i in range(1900, 2024)}.union({'S/A'})

# %%
# read raw content
with open('v1-cleaned.txt', 'r') as f:
    content_raw = f.read()
content_raw[:100]
# Out:
# '\n\n\n\n\nMEZZE BOTTIGLIE\n\nCHAMPAGNE E SPUMANTI\n\nS/A\tRUINART BLANC DE BLANCS\tRUINART\n\t\t\t€ 90,00\n\nS/A\tRUIN'

# %%
# remove multiple spaces, tabs and newlines

import re
content = re.sub(r'\n+', '\n', content_raw)
content = re.sub(r'  +', '\t', content)
content = re.sub(r'\(', '\t', content)
content = re.sub(r'\)', '\t', content)
content = re.sub(r'\t+', '\t', content)
content[:100]
# Out:
# "\nMEZZE BOTTIGLIE\nCHAMPAGNE E SPUMANTI\nS/A\tRUINART BLANC DE BLANCS\tRUINART\n\t€ 90,00\nS/A\tRUINART ROSE'"

# %%
# split content into lines

content_lines = content.split('\n')

print(len(content_lines), "content lines")
display(content_lines[69:80])

# drop header lines
print("Header lines to drop:")
for i, line in enumerate(content_lines):
    if "€" not in line and "\t" not in line and line not in years:
        print(i, line)

content_lines = [line for line in content_lines if "€" in line or "\t" in line or line in years]
content_lines[69:90]
# Out:
# 1854 content lines
# ['2002\tFratelli Lunelli\t€ 550,00',
#  '2008\tGIULIO FERRARI RIS. DEL FONDATORE\tFERRARI',
#  '2010\tFratelli Lunelli\t€ 240,00',
#  '2007\tGIULIO FERRARI RIS. DEL FONDATORE\tMagnum\tFERRARI',
#  '2008\tFratelli Lunelli\t€ 480,00',
#  '2009',
#  'SPUMANTI\tITALIANI',
#  '2018\tBRUT\tKETTMEIER',
#  '\t€ 42,00',
#  "2010\tBRUT METODO CLASSICO ''TOMBOLA DI PIN''\tDE STEFANI",
#  '\t€ 50,00']
# Header lines to drop:
# 0
# 1 MEZZE BOTTIGLIE
# 2 CHAMPAGNE E SPUMANTI
# 17 BIANCHI
# 34 ROSSI
# 49 SPUMANTI E CHAMPAGNE
# 50 ITALIANI
# 51 TRENTO DOC
# 98 IL FRANCIACORTA
# 131 IL PROSECCO
# 142 CHAMPAGNE
# 143 MONTAGNE DE REIMS
# 232 COTE DES BAR
# 235 COTE DES BLANCS
# 332 VALLE DE LA MARNE
# 413 VINI BIANCHI
# 414 VENETO
# 433 ALTO ADIGE - TRENTINO
# 497 FRIULI VENEZIA GIULIA
# 564 ABRUZZO
# 580 CAMPANIA
# 592 LOMBARDIA
# 597 MARCHE
# 614 PIEMONTE
# 627 PUGLIA
# 632 SARDEGNA
# 637 SICILIA
# 646 TOSCANA
# 661 UMBRIA
# 675 FRANCIA
# 676 ALSACE
# 685 BOURGOGNE
# 694 CHABLIS
# 697 CORTON CHARLEMAGNE
# 709 LADOIX-SERRIGNY
# 714 MEURSAULT
# 748 LE MONTRACHET
# 786 JURA
# 791 JURANCON
# 794 LANGUEDOC-ROUSSILLON
# 803 VALLE DELLA LOIRA
# 817 AUSTRIA
# 845 GERMANIA
# 846 MOSEL-SAAR-RUWER
# 867 NAHE
# 876 RHEINGAU
# 889 RHINEHESSEN
# 892 PFALZ
# 901 SLOVENIA
# 914 SPAGNA
# 919 VINI ROSSI
# 920 AMARONE E VALPOLICELLA
# 921 COMUNE DI FUMANE
# 937 COMUNE DI POIANO
# 942 COMUNE DI GREZZANA
# 945 COMUNE DI NEGRAR
# 950 COMUNE DI SAN PIETRO IN CARIANO
# 953 COMUNE DI ILLASI
# 960 COMUNE DI MARANO DI VALPOLICELLA
# 963 COMUNE DI MEZZANO DI SOTTO
# 966 COMUNE DI PESCHIERA DEL GARDA
# 973 VENETO
# 988 ABRUZZO
# 997 CAMPANIA
# 1007 EMILIA ROMAGNA
# 1010 FRIULI VENEZIA GIULIA
# 1036 LOMBARDIA
# 1039 MARCHE
# 1042 PIEMONTE
# 1073 IL BARBARESCO
# 1100 IL BAROLO
# 1101 COMUNE DI BAROLO
# 1135 COMUNE DI VERDUNO
# 1152 COMUNE DI ALBA
# 1155 COMUNE DI CASTIGLIONE FALLETTO
# 1170 COMUNE DI NEIVE
# 1186 COMUNE DI LA MORRA
# 1199 COMUNE DI MONFORTE D'ALBA
# 1250 PUGLIA
# 1255 SARDEGNA
# 1270 SICILIA
# 1289 TOSCANA
# 1319 I SUPER TUSCAN
# 1366 IL BRUNELLO DI MONTALCINO
# 1414 BOLGHERI
# 1485  ALTO ADIGE
# 1542 VINI ROSSI STRANIERI
# 1543 FRANCIA
# 1544 BORDEAUX
# 1545 MEDOC - GRAVES
# 1550 MARGAUX
# 1555 PESSAC-LEOGNAN
# 1560 PUILLAC
# 1581 POMEROL
# 1602 SAINT-EMILION
# 1605 BOURGOGNE ROUGE
# 1622 GEVREY- CHAMBERTIN
# 1641 MOREY -SAINT-DENIS
# 1660 CHAMBOLLE-MUSIGNY
# 1669 CLOS-DE-VOUGEOT
# 1676 VOSNE-ROMANEE
# 1701 NUITS-SAINT-GEORGES
# 1708 PERNAND-VERGELESSES
# 1714 POMMARD - VOLNAY
# 1727 VALLE DELLA LOIRA
# 1732 COTES DU RHONE
# 1749 CAHORS
# 1754 SLOVENIA
# 1761 SPAGNA-RIOJA
# 1768 SVIZZERA
# 1769 VALLE DEL RENO DEI GRIGIONI
# 1772 LIBANO
# 1775 CALIFORNIA
# 1776 NAPA VALLEY
# 1781 SONOMA COAST
# 1784 AUSTRALIA
# 1785 BAROSSA VALLEY
# 1788 VINI DA DESSERT ITALIANI ED ESTERI
# 1789 VENETO
# 1798 FRIULI VENEZIA GIULIA
# 1801 PIEMONTE
# 1806 SICILIA
# 1815 TRENTINO ALTO ADIGE
# 1820 FRANCIA
# 1831 LANGUEDOC-ROUSSILLON
# 1836 SPAGNA
# 1841 PORTOGALLO
# 1844 UNGHERIA
# 1853
# ['\t€ 42,00',
#  "2010\tBRUT METODO CLASSICO ''TOMBOLA DI PIN''\tDE STEFANI",
#  '\t€ 50,00',
#  'S/A\tBLANC DE BLANC\tMETODO CLASSICO EXTRA BRUT\tVILLA PARENS',
#  '\t€ 40,00',
#  '2013\tBRUT DURELLO \tBELLAGUARDIA',
#  '\t€ 45,00',
#  "2016\tBRUT ROSE'\tBELLAGUARDIA",
#  '\t€ 58,00',
#  "S/A\tDURELLO PAS DOSE'\tDAL MASO",
#  '\t€ ,00',
#  "S/A\tEXTRA BRUT CUVEE' MARIANNA\tARUNDA\t",
#  '\t€ 68,00',
#  '2016\tLEONIA POMINO BRUT\tFRESCOBALDI',
#  '\t€ 45,00',
#  "2014\tMATT '55\tPIAN DELLE VETTE",
#  '\t€ 65,00',
#  '2012\tPLUK BLANC DE NOIR BRUT NATURE\tBELLENDA',
#  '\t€ 56,00',
#  '2008\tWURM BLANC DE BLANC BRUT NATURE\tBELLENDA',
#  '\t€ 60,00']

# %%
content_lines[65]
# Out:
# '2008\tFratelli Lunelli\t€ 480,00'

# %%
# join lines that belong to the same wine

"""This code is ugly, but it works.
The issue is that the lines that belong to the same wine are not always consecutive.

"""

wine_lines = []
wine_line = ''

i = 0
while i<len(content_lines):
    # ignore lines that do not start with a year
    if not content_lines[i].split('\t')[0].strip() in years:
        i+=1
        continue

    # join lines that belong to the same wine, until you find a "€" sign
    wine_line = content_lines[i]
    i+=1
    while "€" not in content_lines[i] and i<len(content_lines):
        wine_line += '\t' + content_lines[i]
        i+=1
    if i>=len(content_lines): # avoid out of bounds
        break

    wine_line += '\t' + content_lines[i] # add the line with the "€" sign
    i+=1
    if i>=len(content_lines): # avoid out of bounds
        break

    # add additional years to the wine line
    while content_lines[i].strip() in years and i<len(content_lines):
        wine_line += '\t' + content_lines[i]
        i+=1

    wine_lines.append(re.sub(r'\t+', '\t', wine_line))
    wine_line = ''

wine_lines[:40]
# Out:
# ['S/A\tRUINART BLANC DE BLANCS\tRUINART\t€ 90,00',
#  "S/A\tRUINART ROSE'\tRUINART\t€ 90,00",
#  'S/A\tEXTRA BRUT PREMIERE CUVEE\tBRUNO PAILLARD\t€ 65,00',
#  'S/A\tBRUT CHAMPAGNE\tSPECIAL CUVEE\tBOLLINGER\t€ 75,00',
#  'S/A\tBRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS\tPERTOIS MORISET\t€ 60,00',
#  'S/A\tBRUT ROEDERER COLLECTION 244\tLOUIS ROEDERER\tLouis Roederer\t€ 65,00',
#  "S/A\tEXTRA BRUT CUVEE' MARIANNA\tARUNDA\t€ 36,00",
#  '2020\tCORTON CHARLEMAGNE \t BONNEAU DU MARTRAY\tGrand Cru\t€ ,00',
#  '2021\tCHAMPAGNIS CHARDONNAY \t VIE DE ROMANS\t€ 30,00',
#  '2021\tCERVARO DELLA SALA\t ANTINORI\t2022\t€ 65,00',
#  '2021\tDESSIMIS PINOT GRIGIO\tVIE DE ROMANS\t€ 30,00',
#  '2022\tSAUVIGNON\tCANTINA S. MICHELE APPIANO\t€ 30,00',
#  '2022\tSAUVIGNON LAFOA\tCOLTERENZIO\t€ 35,00',
#  '2021\tVIERIS SAUVIGNON\tVIE DE ROMANS\t€ 30,00',
#  '2018\tGAJA E REY\tGAJA\t€ 240,00',
#  '2018\tAMARONE\tALLEGRINI\tdoc della Valpolicella\t€ 75,00',
#  '2020\tCHIANTI CLASSICO\tFONTODI\t€ 24,00',
#  '2021\tPINOT NERO PATRICIA\tGIRLAN\t€ 26,00',
#  '2020\tROCCA RUBIA\tSANTADI\t€ .00',
#  "2020\tORNELLAIA\tTENUTA DELL'ORNELLAIA\tBolgheri Superiore\t€ 180,00",
#  '2017\tRIPASSA\tZENATO\t2019\tdoc della Valpolicella\t€ 24,00',
#  '2019\tSASSICAIA\tTENUTA SAN GUIDO\t2020\tdoc Bolgheri\t€ 190,00',
#  '2018\tALTEMASI\tCAVIT\tTrento Doc\t€ 38,00',
#  '2015\tOPERA BRUT\tCORVEE\tTrento Doc\t€ 40,00',
#  "2017\tBRUT FERRARI PERLE'\tFERRARI\tFratelli Lunelli\t€ 70,00",
#  "2016\tBRUT FERRARI PERLE' ROSE'\tMagnum\tFERRARI\tFratelli Lunelli\t€ 170,00",
#  "2016\tBRUT FERRARI PERLE' ROSE'\tFERRARI\tFratelli Lunelli\t€ 80,00",
#  "2015\tBRUT FERRARI PERLE' BIANCO \tFERRARI\tFratelli Lunelli\t€ 80,00",
#  "2014\tBRUT FERRARI PERLE' CUVEE ZERO\tFERRARI\tFratelli Lunelli\t€ 100,00",
#  "2013\tBRUT FERRARI PERLE' NERO\tFERRARI\tFratelli Lunelli\t€ 110,00",
#  '2001\tGIULIO FERRARI RIS. DEL FONDATORE COLLEZIONE\tFERRARI\t2002\tFratelli Lunelli\t€ 550,00',
#  '2008\tGIULIO FERRARI RIS. DEL FONDATORE\tFERRARI\t2010\tFratelli Lunelli\t€ 240,00',
#  '2007\tGIULIO FERRARI RIS. DEL FONDATORE\tMagnum\tFERRARI\t2008\tFratelli Lunelli\t€ 480,00\t2009',
#  '2018\tBRUT\tKETTMEIER\t€ 42,00',
#  "2010\tBRUT METODO CLASSICO ''TOMBOLA DI PIN''\tDE STEFANI\t€ 50,00",
#  'S/A\tBLANC DE BLANC\tMETODO CLASSICO EXTRA BRUT\tVILLA PARENS\t€ 40,00',
#  '2013\tBRUT DURELLO \tBELLAGUARDIA\t€ 45,00',
#  "2016\tBRUT ROSE'\tBELLAGUARDIA\t€ 58,00",
#  "S/A\tDURELLO PAS DOSE'\tDAL MASO\t€ ,00",
#  "S/A\tEXTRA BRUT CUVEE' MARIANNA\tARUNDA\t€ 68,00"]

# %% [markdown]
# ## Create clean wine info

# %%
import pandas as pd

# %%
formats = {'Magnum', 'Doppio Magnum', '6L', '6l', 'Piccolo'}

# %%
for wine_line in wine_lines:
    if any(format.lower() in wine_line.lower() for format in formats):
        # print(wine_line)
        pass

wine_info = []

for line in wine_lines:
    naming = [l.strip() for l in line.split('\t') if l not in years and l not in formats and '€' not in l]
    naming = [n for n in naming if n]
    format = [l.strip() for l in line.split('\t') if l in formats]
    format = format[0] if format else 'standard'
    vintages = [l.strip() for l in line.split('\t') if l in years]
    price = [l.strip() for l in line.split('\t') if '€' in l]

    wine_info.append({
        'naming': naming,
        'format': format,
        'years': vintages,
        'price': price
    })

wine_info[:5]
# Out:
# [{'naming': ['RUINART BLANC DE BLANCS', 'RUINART'],
#   'format': 'standard',
#   'years': ['S/A'],
#   'price': ['€ 90,00']},
#  {'naming': ["RUINART ROSE'", 'RUINART'],
#   'format': 'standard',
#   'years': ['S/A'],
#   'price': ['€ 90,00']},
#  {'naming': ['EXTRA BRUT PREMIERE CUVEE', 'BRUNO PAILLARD'],
#   'format': 'standard',
#   'years': ['S/A'],
#   'price': ['€ 65,00']},
#  {'naming': ['BRUT CHAMPAGNE', 'SPECIAL CUVEE', 'BOLLINGER'],
#   'format': 'standard',
#   'years': ['S/A'],
#   'price': ['€ 75,00']},
#  {'naming': ['BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS', 'PERTOIS MORISET'],
#   'format': 'standard',
#   'years': ['S/A'],
#   'price': ['€ 60,00']}]

# %%
# sanity check on price
for i, info in enumerate(wine_info):
    if len(info['price']) > 1:
        print(i, info)

# Oh no! There are some lines with 2 wines! Let's split them manually
# The reason is that there is no new line between the wines
# I solve this in the most basic way, by correcting v1-cleaned.txt
# So after the correction here there will be nothing

# %%
# sanity check on naming: length equal to 3
n = 0
for i, info in enumerate(wine_info):
    if len(info['naming']) == 3:
        n+=1
        print(i, info['naming'])
print(n)
# Out:
# 3 ['BRUT CHAMPAGNE', 'SPECIAL CUVEE', 'BOLLINGER']
# 5 ['BRUT ROEDERER COLLECTION 244', 'LOUIS ROEDERER', 'Louis Roederer']
# 7 ['CORTON CHARLEMAGNE', 'BONNEAU DU MARTRAY', 'Grand Cru']
# 15 ['AMARONE', 'ALLEGRINI', 'doc della Valpolicella']
# 19 ['ORNELLAIA', "TENUTA DELL'ORNELLAIA", 'Bolgheri Superiore']
# 20 ['RIPASSA', 'ZENATO', 'doc della Valpolicella']
# 21 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 22 ['ALTEMASI', 'CAVIT', 'Trento Doc']
# 23 ['OPERA BRUT', 'CORVEE', 'Trento Doc']
# 24 ["BRUT FERRARI PERLE'", 'FERRARI', 'Fratelli Lunelli']
# 25 ["BRUT FERRARI PERLE' ROSE'", 'FERRARI', 'Fratelli Lunelli']
# 26 ["BRUT FERRARI PERLE' ROSE'", 'FERRARI', 'Fratelli Lunelli']
# 27 ["BRUT FERRARI PERLE' BIANCO", 'FERRARI', 'Fratelli Lunelli']
# 28 ["BRUT FERRARI PERLE' CUVEE ZERO", 'FERRARI', 'Fratelli Lunelli']
# 29 ["BRUT FERRARI PERLE' NERO", 'FERRARI', 'Fratelli Lunelli']
# 30 ['GIULIO FERRARI RIS. DEL FONDATORE COLLEZIONE', 'FERRARI', 'Fratelli Lunelli']
# 31 ['GIULIO FERRARI RIS. DEL FONDATORE', 'FERRARI', 'Fratelli Lunelli']
# 32 ['GIULIO FERRARI RIS. DEL FONDATORE', 'FERRARI', 'Fratelli Lunelli']
# 35 ['BLANC DE BLANC', 'METODO CLASSICO EXTRA BRUT', 'VILLA PARENS']
# 44 ['BRUT FRANCIACORTA DOPPIO ERRE DI', 'DERBUSCO CIVES', 'docg Franciacorta']
# 46 ['BRUT FRANCIACORTA ROSE’', 'BELLAVISTA', 'docg Franciacorta']
# 49 ['BRUT FRANCIACORTA BLANC DE BLANCS ZERO’', 'BELLAVISTA', 'docg Franciacorta']
# 50 ['BRUT FRANCIACORTA RISERVA VITTORIO MORETTI', 'BELLAVISTA', 'docg Franciacorta']
# 51 ['BRUT FRANCIACORTA BLANC', 'CONTADI CASTALDI', 'docg Franciacorta']
# 52 ['BRUT FRANCIACORTA CRU PERDU GRAN ANNATA', 'BONOMI', 'docg Franciacorta']
# 53 ['BRUT FRANCIACORTA PRESTIGE', "CA' DEL BOSCO", 'docg Franciacorta']
# 54 ['BRUT FRANCIACORTA PRESTIGE', "CA' DEL BOSCO", 'docg Franciacorta']
# 55 ["BRUT FRANCIACORTA PRESTIGE ROSE'", "CA' DEL BOSCO", 'docg Franciacorta']
# 56 ["BRUT FRANCIACORTA PRESTIGE ROSE'", "CA' DEL BOSCO", 'docg Franciacorta']
# 57 ["BRUT FRANCIACORTA ZERO'", "CA' DEL BOSCO", 'docg Franciacorta']
# 58 ['BRUT CUVEE ANNAMARIA CLEMENTI', "CA' DEL BOSCO", 'docg Franciacorta']
# 59 ["BRUT CUVEE ANNAMARIA CLEMENTI ROSE'", "CA' DEL BOSCO", 'docg Franciacorta']
# 61 ['PROSECCO SUPERIORE SC 1931', 'BELLENDA', 'Prosecco Doc']
# 62 ['PROSECCO BRUT', 'BIANCAVIGNA', 'docg Conegliano Valdobbiadene']
# 63 ['PROSECCO SUP. BRUT NATURE RIVE DI OGLIANO', 'BIANCAVIGNA', 'docg Conegliano Valdobbiadene']
# 64 ["PROSECCO SUP. DOSAGE ZERO' RIVE DI SOLIGO", 'BIANCAVIGNA', 'docg Conegliano Valdobbiadene']
# 67 ["EXTRA BRUT CHAMP. SABLE' ROSE", 'AUBRY', 'Premier Cru']
# 88 ['BRUT ROEDERER PREMIER VINTAGE', 'LOUIS ROEDERER', 'Louis Roederer']
# 89 ["BRUT ROEDERER PREMIER ROSE'", 'LOUIS ROEDERER', 'Louis Roederer']
# 90 ['BRUT ROEDERER COLLECTION 244', 'LOUIS ROEDERER', 'Louis Roederer']
# 91 ['BRUT ROEDERER COLLECTION 243', 'LOUIS ROEDERER', 'Louis Roederer']
# 92 ['BRUT ROEDERER COLLECTION 242', 'LOUIS ROEDERER', 'Louis Roederer']
# 93 ['BRUT ROEDERER COLLCTION 243', 'LOUIS ROEDERER', 'Louis Roederer']
# 94 ['BRUT ROEDERER ROSE’', 'LOUIS ROEDERER', 'Louis Roederer']
# 99 ['BRUT KRUG GRANDE CUVEE', 'KRUG', 'Krug']
# 100 ['BRUT KRUG GRANDE CUVEE', 'KRUG', 'Krug']
# 120 ['EXTRA BRUT CHAMPAGNE LA CLOSERIE', '&', 'JEROME PREVOST']
# 138 ["BRUT CHAMP. ROSE'", 'JACQUES SELOSSE', 'Grand Cru']
# 139 ['BRUT CHAMPAGNE INITIAL BLANC DE BLANC', 'JACQUES SELOSSE', 'Grand Cru']
# 140 ['SUBSTANCE', 'JACQUES SELOSSE', 'Grand Cru']
# 141 ['EXTRABRUT CHAMP. LES BOUTS DU CLOS AMBONNAY GRAND CRU', 'J. SELOSSE', 'Grand Cru']
# 146 ['EXTRABRUT CHAMP.', 'BLANC DE NOIRS LARGILLIER', 'GUILLAUME SELOSSE']
# 154 ['BRUT', 'CHAMP. CUVEE WINSTON CHURCHILL', 'POL ROGER']
# 156 ['SALON BLANC DE BLANCS', 'SALON', 'Salon']
# 161 ['BRUT DOM PERIGNON P3', 'MOET CHANDON', 'Moet Chandon']
# 162 ['BRUT DOM PERIGNON P2', 'MOET CHANDON', 'Moet Chandon']
# 163 ["BRUT DOM PERIGNON ROSE'", 'MOET CHANDON', 'Moet Chandon']
# 164 ["BRUT DOM PERIGNON ROSE' LIMITED EDITION LADY GAGA", 'MOET CHANDON', 'Moet Chandon']
# 165 ['BRUT DOM PERIGNON', 'MOET CHANDON', 'Moet Chandon']
# 166 ['BRUT DOM PERIGNON', 'MOET CHANDON', 'Moet Chandon']
# 167 ['BRUT DOM PERIGNON', 'MOET CHANDON', 'Moet Chandon']
# 168 ['BRUT DOM PERIGNON LIMITED EDITION LADY GAGA', 'MOET CHANDON', 'Moet Chandon']
# 169 ['BRUT DOM PERIGNON', 'MOET CHANDON', 'Moet Chandon']
# 170 ['BRUT DOM PERIGNON', 'MOET CHANDON', 'Moet Chandon']
# 188 ['BRUT', 'NATURE CHAMPAGNE FLUENCE', 'FRANCK PASCAL']
# 204 ['SOAVE LE BINE DI COSTIOLA', 'TAMELLINI', 'doc Soave Classico']
# 208 ['CHARDONNAY', 'MAGRED', 'NALS MARGREID']
# 209 ['CHARDONNAY', 'GAUN', 'LAGEDER']
# 210 ['CHARDONNAY', 'LOWENGANG', 'LAGEDER']
# 211 ['CHARDONNAY', 'SOMERETO', 'ANDRIAN']
# 212 ['CHARDONNAY', 'DORAN', 'ANDRIAN']
# 216 ['WEISSWEIN DOLOMYTOS', 'ANSITZ', 'DOLOMYTOS']
# 220 ['NOVA DOMUS', 'TERLANO', 'doc Alto Adige']
# 223 ['RARITY PINOT BIANCO', 'TERLANO', 'doc Alto Adige Terlano']
# 224 ['SAUVIGNON', 'ST. VALENTIN', 'CANTINA S. MICHELE APPIANO']
# 225 ['SAUVIGNON LIEBEN AICH BIO', 'MANINCOR', 'doc Alto Adige']
# 226 ['SAUVIGNON LIEBEN AICH BIO', 'MANINCOR', 'doc Alto Adige']
# 227 ['SAUVIGNON MOCK', 'ST. MAGDALENA', 'doc Alto Adige']
# 228 ['SAUVIGNON VOGLAR', 'PETER DIPOLI', 'doc Alto Adige']
# 229 ['SAUVIGNON QUARZ', 'TERLANO', 'doc Alto Adige']
# 230 ['SAUVIGNON QUARZ', 'TERLANO', 'doc Alto Adige']
# 231 ['SAUVIGNON QUARZ', 'TERLANO', 'doc Alto Adige']
# 232 ['SYLVANER', '“R”', 'KOFERERHOF']
# 240 ['CHARDONNAY', 'CIAMPAGNIS', 'VIE DI ROMANS']
# 243 ['COLLIO BIANCO', 'BORGO DEL TIGLIO', 'Collio DOC']
# 260 ['SAUVIGNON', 'BORGO DEL TIGLIO', 'Collio DOC']
# 265 ['VITOVSKA', 'ZIDARICH', 'doc Carso']
# 266 ['VITOVSKA', 'ZIDARICH', 'doc Carso']
# 267 ['VITOVSKA', 'VODOPIVEC', 'doc Carso']
# 279 ["NEROAMETA'", 'MASTROBERARDINO', 'Campania Bianco Igt']
# 281 ['UCCELLANDA', "CA' DEL BOSCO", 'doc Curtefranca']
# 282 ['UCCELLANDA', "CA' DEL BOSCO", 'doc Curtefranca']
# 297 ['TORMARESCA BIANCO', 'TORMARESCA', 'da uve chardonnay']
# 299 ['CAPICHERA', 'CAPICHERA', 'vermentino di Gallura']
# 304 ['TIRSAT', 'FEUDI DEL PISCIOTTO', 'Chardonnay e Viognier']
# 321 ['BOURGOGNE BLANC', 'CUVEE SAINT VINCENT', 'VINCENT GIRARDIN']
# 326 ['CORTON CHARLEMAGNE', 'LOUIS LATOUR', 'A. Corton Grand Cru Controlée']
# 327 ['CORTON CHARLEMAGNE', 'DOMAINE BONNEAU DU MARTRAY', 'A. Corton Grand Cru Controlée']
# 328 ['CORTON CHARLEMAGNE', 'DOMAINE DE LA ROMANEE CONTI', 'A. Corton Grand Cru Controlée']
# 329 ['CORTON CHARLEMAGNE', 'LOUIS JADOT', 'A. Corton Grand Cru Controlée']
# 330 ['QUINTESSENCE DE CORTON CHARLEMAGNE', 'VINCENT GIRARDIN', 'A. Corton Grand Cru Controlée']
# 333 ['MEURSAULT NARVAUX', 'DOMAINE MICHELOT', 'a. Meursault c.']
# 334 ['MEURSAULT SOUS LA VELLE', 'DOMAINE MICHELOT', 'a. Meursault c.']
# 335 ['MEURSAULT LES NARVAUX', 'VINCENT GIRARDIN', 'a. Meursault c.']
# 336 ['MEURSAULT VIEILLES VIGNES', 'VINCENT GIRARDIN', 'a. Meursault c.']
# 337 ['MEURSAULT 1ER CRU LES GENEVRIERES', 'VINCENT GIRARDIN', 'a. Meursault c.']
# 338 ['MEURSAULT', 'CHRISTIAN BELLANG', 'a. Meursault c.']
# 339 ['MEURSAULT 1ER CRU PORUZOTS VIELLES VIGNES', 'DOMINIQUE LAURENT', 'a. Meursault c.']
# 340 ["MEURSAULT 1ER CRU LES GOUTTE D'OR", 'LOUIS LATOUR', 'a. Meursault c.']
# 341 ['MEURSAULT', 'DOMAINE JEAN MICHEL GAUNOUX', 'a. Meursault c.']
# 342 ['MEURSAULT 1ER CRU PERRIERES', 'DOMAINE JEAN MICHEL GAUNOUX', 'a. Meursault c.']
# 343 ['MEURSAULT', 'COCHE-DURY', 'a. Meursault c.']
# 344 ['MEURSAULT LES PETITS CHARRONS', 'ARNAUD ENTE', 'a. Meursault c.']
# 345 ['MEURSAULT 1ER CRU PERRIERES', 'DOMAINE DES COMTES LAFON', 'a. Meursault c.']
# 346 ['MEURSAULT 1ER CRU PORUZOT', 'DOMAINE DES COMTES LAFON', 'a. Meursault c.']
# 347 ["MEURSAULT 1ER CRU LES GOUTTE D'OR", 'DOMAINE DES COMTES LAFON', 'a. Meursault c.']
# 348 ['MEURSAULT CHARMES', 'DOMAINE DES COMTES LAFON', 'a. Meursault c.']
# 350 ['CHEVALIER-MONTRACHET LES DEMOISELLES', 'LOUIS LATOUR', 'Grand Cru']
# 351 ['CHEVALIER-MONTRACHET', "LEROY-D'AUVENAY", 'Grand Cru']
# 352 ['CHEVALIER-MONTRACHET', 'LEFLAIVE', 'Grand Cru']
# 353 ['CHEVALIER-MONTRACHET', 'DOMAINE DE LA VOUGERAIRE', 'Grand Cru']
# 354 ['MONTRACHET', 'LOUIS LATOUR', 'Grand cru']
# 355 ['MONTRACHET', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand cru']
# 356 ['MONTRACHET', 'DOMAINE DES COMTES LAFON', 'Grand cru']
# 357 ['MONTRACHET', 'DOMAINE DES COMTES LAFON', 'Grand cru']
# 358 ['PULIGNY-MONTRACHET 1ER CRU LES CHAMPS GAIN', 'a. Puligny Montrachet c.', 'DOMAINE DE LA VOUGERAIE']
# 360 ['PULIGNY-MONTRACHET', 'VINCENT GIRARDIN', 'a. Puligny Montrachet c.']
# 361 ['PULIGNY-MONTRACHET', 'DOMAINE MICHELOT', 'a. Puligny Montrachet c.']
# 362 ['PULIGNY-MONTRACHET', "DOMAINE ANDRE' GOICHOT", 'a. Puligny Montrachet c.']
# 363 ['PULIGNY-MONTRACHET FOLATIERES', 'DOMAINE FRANCOIS GAUNOUX', 'a. Puligny Montrachet c.']
# 364 ['PULIGNY-MONTRACHET LES PUCELLES', 'DOMAINE LEFLAIVE', 'a. Puligny Montrachet c.']
# 365 ['PULIGNY-MONTRACHET 1ER CRU CLOS DE LA MOUCHERE', 'a. Puligny Montrachet c.', 'DOMAINE BOILLOT']
# 371 ['MARIETA', 'BIO', 'DOMAINE DES DEMOISELLES']
# 386 ['RIESLING', 'MORDTHAL 1 LAGE BIO', 'KARL FRITSCH']
# 389 ['RIESLING', 'SMARAGD VOM STEIN', 'NIKOLAIHOF']
# 390 ['RIESLING', 'STEINER HUND', 'NIKOLAIHOF']
# 392 ['RIESLING', 'UNDHOF', 'SALOMON']
# 393 ['RIESLING FANTASIE DER SCHIEFERTERRASSEN', 'Riesling spumante metodo classico', 'HEYMANN-LOWENSTEIN']
# 394 ['RIESLING', 'SCHIEFERTERRASSEN', 'HEYMANN-LOWENSTEIN']
# 395 ['RIESLING', 'SCHWARZHOFBERGER QBA', 'EGON MULLER']
# 397 ['RIESLING', 'BLAUSCHIEFER', 'DR LOOSEN']
# 401 ['RIESLING', 'WEHLENER SONNENUHR KABINETT', 'J.J.PRUM']
# 403 ['RIESLING', 'TONSCHIEFER QBA TROCKEN', 'DONNHOFF']
# 406 ['RIESLING', 'SCHIEFER', 'ADELSEK']
# 410 ['RIESLING 50°', 'SCHLOSS', 'JOHANNISBERG']
# 418 ['CHARDONNAY', 'SELECTION', 'SIMCIC']
# 421 ['REBULA', 'SELECTION', 'SIMCIC']
# 422 ['SAUVIGNON', 'SELECTION', 'SIMCIC']
# 428 ['LA POJA', 'ALLEGRINI', 'da uve corvina veronese']
# 429 ['LA POJA', 'ALLEGRINI', 'da uve corvina veronese']
# 437 ['AMARONE', 'REIUS', 'SARTORI']
# 444 ['AMARONE', 'ZENATO', 'doc della Valpolicella']
# 445 ['RIPASSA', 'ZENATO', 'doc Valpolicella']
# 446 ['RIPASSA', 'ZENATO', 'doc Valpolicella']
# 454 ["MONTEPULCIANO D'ABRUZZO", 'VALENTINI', 'doc Montepulciano']
# 455 ["MONTEPULCIANO D'ABRUZZO", 'VALENTINI', 'doc Montepulciano']
# 456 ["MONTEPULCIANO D'ABRUZZO", 'EMIDIO PEPE', 'doc Montepulciano']
# 457 ["MONTEPULCIANO D'ABRUZZO RISERVA", 'MARINA CVETIC', 'doc Montepulciano']
# 477 ['BARBERA VIGNA FRANCIA', 'GIACOMO CONTERNO', 'doc Barbera']
# 478 ['BARBERA VIGNA FRANCIA', 'GIACOMO CONTERNO', 'doc Barbera']
# 479 ["BARBERA D'ALBA AVES", 'BURLOTTO', 'doc Barbera']
# 482 ['FORAVIA', 'Doppia Manum', 'MORRA GABRIELE']
# 483 ['GATTINARA', 'NERVI', 'Docg']
# 484 ['GATTINARA VIGNA VALFERANA', 'NERVI', 'Docg']
# 485 ['GHEMME VIGNA PELLIZZANE', 'TORRACCIA DEL PIANTAVIGNA', 'Docg']
# 491 ['VERDUNO PELAVERGA', 'BURLOTTO', 'doc Pelaverga']
# 492 ['BARBARESCO', 'PRODUTTORI BARBARESCO', 'docg Barbaresco']
# 493 ['BARBARESCO', 'PRODUTTORI BARBARESCO', 'docg Barbaresco']
# 494 ['BARBARESCO BASARIN', 'AZ. AGR. NEGRO', 'docg Barbaresco']
# 495 ["BARBARESCO CRICHET PAJE'", 'ROAGNA', 'docg Barbaresco']
# 496 ["BARBARESCO CRICHET PAJE'", 'ROAGNA', 'docg Barbaresco']
# 497 ['BARBARESCO', 'CORTESE', 'docg Barbaresco']
# 501 ['BARBARESCO', 'CORTESE', 'docg Barbaresco']
# 503 ['BARBARESCO ASILI RIS. FALLETTO E.R.', 'BRUNO GIACOSA', 'docg Barbaresco']
# 504 ['BARBARESCO ASILI RIS. FALLETTO E.R.', 'BRUNO GIACOSA', 'docg Barbaresco']
# 508 ['BAROLO BRUNATE', 'GIUSEPPE RINALDI', 'docg Barolo']
# 509 ['BAROLO BRUNATE', 'GIUSEPPE RINALDI', 'docg Barolo']
# 510 ['BAROLO TRE TINE', 'GIUSEPPE RINALDI', 'docg Barolo']
# 511 ['BAROLO TRE TINE', 'GIUSEPPE RINALDI', 'docg Barolo']
# 512 ['BAROLO TRE TINE', 'GIUSEPPE RINALDI', 'docg Barolo']
# 513 ['BAROLO', 'BARTOLO MASCARELLO', 'docg Barolo']
# 514 ['BAROLO', 'BARTOLO MASCARELLO', 'docg Barolo']
# 515 ['BAROLO', 'BARTOLO MASCARELLO', 'docg Barolo']
# 516 ['BAROLO', 'BARTOLO MASCARELLO', 'docg Barolo']
# 517 ['BAROLO', 'BARTOLO MASCARELLO', 'docg Barolo']
# 520 ['BAROLO BRICCO DELLE VIOLE', 'VAJRA', 'docg Barolo']
# 521 ['BAROLO', 'BURLOTTO', 'docg Barolo']
# 522 ['BAROLO MONVIGLIERO', 'BURLOTTO', 'docg Barolo']
# 523 ['BAROLO MONVIGLIERO', 'BURLOTTO', 'docg Barolo']
# 524 ['BAROLO MONVIGLIERO', 'BURLOTTO', 'docg Barolo']
# 525 ['BAROLO MONVIGLIERO', 'BURLOTTO', 'docg Barolo']
# 526 ['BAROLO ACCLIVI', 'BURLOTTO', 'docg Barolo']
# 527 ['BAROLO CANNUBI', 'BURLOTTO', 'docg Barolo']
# 528 ['BAROLO CANNUBI', 'BURLOTTO', 'docg Barolo']
# 529 ['BAROLO', 'PIO CESARE', 'docg Barolo']
# 532 ['BAROLO RAVERA', 'VIETTI', 'docg Barolo']
# 533 ['BAROLO LE ROCCHE DI CASTIGLIONE', 'VIETTI', 'docg Barolo']
# 534 ['BAROLO MONVIGLIERO', 'VIETTI', 'docg Barolo']
# 535 ['BAROLO RISERVA VILLERO', 'VIETTI', 'docg Barolo']
# 536 ['BAROLO VECCHIE VITI', 'ROCCHE VIBERTI', 'docg Barolo']
# 537 ['BAROLO LE ROCCHE DEL FALLETTO RISERVA E.R.', 'BRUNO GIACOSA', 'docg Barolo']
# 538 ['BAROLO LE ROCCHE DEL FALLETTO RISERVA E.R.', 'BRUNO GIACOSA', 'docg Barolo']
# 539 ['BAROLO LE ROCCHE DEL FALLETTO RISERVA E.R.', 'BRUNO GIACOSA', 'docg Barolo']
# 540 ['BAROLO', 'BRUNO GIACOSA', 'docg Barolo']
# 541 ['BAROLO FALLETTO', 'BRUNO GIACOSA', 'docg Barolo']
# 542 ['BAROLO FALLETTO VIGNA LE ROCCHE', 'BRUNO GIACOSA', 'docg Barolo']
# 543 ['BAROLO FALLETTO VIGNA LE ROCCHE', 'BRUNO GIACOSA', 'docg Barolo']
# 544 ['BAROLO', 'REVA', 'docg Barolo']
# 545 ['BAROLO', 'CRISSANTE ALESSANDRIA', 'docg Barolo']
# 546 ['BAROLO', 'CRISSANTE ALESSANDRIA', 'docg Barolo']
# 547 ['BAROLO', 'TREDIBERRI', 'docg Barolo']
# 548 ['BAROLO ANNUNZIATA RISERVA', 'CAV. ACCOMASSO', 'docg Barolo']
# 549 ['BAROLO CONTEISA', 'GAJA', 'docg Barolo']
# 550 ['BAROLO RIS. VIGNA BUSSIA PIANPOLVERE SOPRANO', 'PIANPOLVERE SOPRANO', 'docg Barolo']
# 551 ['BAROLO RIS. VIGNA BUSSIA PIANPOLVERE SOPRANO', 'docg Barolo', 'PIANPOLVERE SOPRANO']
# 552 ['BAROLO RIS. VIGNA BUSSIA PIANPOLVERE SOPRANO', 'docg Barolo', 'PIANPOLVERE SOPRANO']
# 553 ['BAROLO ARIONE', 'GIACOMO CONTERNO', 'docg Barolo']
# 554 ['BAROLO ARIONE', 'GIACOMO CONTERNO', 'docg Barolo']
# 555 ['BAROLO FRANCIA', 'GIACOMO CONTERNO', 'docg Barolo']
# 556 ['BAROLO FRANCIA', 'GIACOMO CONTERNO', 'docg Barolo']
# 557 ['BAROLO CERRETTA', 'GIACOMO CONTERNO', 'docg Barolo']
# 558 ['BAROLO CERRETTA', 'GIACOMO CONTERNO', 'docg Barolo']
# 559 ['BAROLO CERRETTA', 'GIACOMO CONTERNO', 'docg Barolo']
# 560 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 561 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 562 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 563 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 564 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 565 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 566 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 567 ['BAROLO RISERVA MONFORTINO', 'GIACOMO CONTERNO', 'docg Barolo']
# 568 ['BAROLO', 'MASSOLINO', 'docg Barolo']
# 569 ['BAROLO RISERVA VIGNA RIONDA', 'MASSOLINO', 'docg Barolo']
# 570 ['BAROLO BUSSIA', 'ALDO CONTERNO', 'docg Barolo']
# 571 ['BAROLO BUSSIA VIGNA COLONNELLO', 'ALDO CONTERNO', 'docg Barolo']
# 572 ['BAROLO BUSSIA VIGNA ROMIRASCO', 'ALDO CONTERNO', 'docg Barolo']
# 573 ['BAROLO GRANBUSSIA', 'ALDO CONTERNO', 'docg Barolo']
# 577 ['ROCCA RUBIA', 'SANTADI', 'Carignano del Sulcis DOC']
# 579 ['TERRE BRUNE', 'SANTADI', 'Carignano del Sulcis DOC']
# 580 ['TERRE BRUNE', 'SANTADI', 'Carignano del Sulcis DOC']
# 581 ['TURRIGA', 'ARGIOLAS', 'Uve cannonau,carignano,bovale sardo']
# 582 ['TURRIGA', 'ARGIOLAS', 'Uve cannonau,carignano,bovale sardo']
# 593 ['COEVO', 'CECCHI', 'Sangiovese, cabernet sauvignon, merlot e petit verdot']
# 614 ['LUCE', 'TENUTA LUCE FRESCOBALDI', 'merlot, sangiovese']
# 615 ['LUCE', 'TENUTA LUCE FRESCOBALDI', 'merlot, sangiovese']
# 616 ['LUCE', 'TENUTA LUCE FRESCOBALDI', 'merlot, sangiovese']
# 617 ['LUCE', 'TENUTA LUCE FRESCOBALDI', 'merlot, sangiovese']
# 618 ['LUX VITIS', 'TENUTA LUCE FRESCOBALDI', 'Cabernet Sauvignon']
# 619 ['LUCENTE', 'TENUTA LUCE FRESCOBALDI', 'merlot, sangiovese']
# 620 ['SOLAIA', 'MARCHESI ANTINORI', 'cabernet sauvignon e sangiovese']
# 621 ['SOLAIA', 'MARCHESI ANTINORI', 'cabernet sauvignon e sangiovese']
# 622 ['SOLAIA', 'MARCHESI ANTINORI', 'cabernet sauvignon e sangiovese']
# 624 ['TIGNANELLO', 'MARCHESI ANTINORI', 'sangiovese e cabernet sauvignon']
# 625 ['TIGNANELLO', 'MARCHESI ANTINORI', 'sangiovese e cabernet sauvignon']
# 626 ['TIGNANELLO', 'MARCHESI ANTINORI', 'sangiovese e cabernet sauvignon']
# 627 ['TIGNANELLO', 'MARCHESI ANTINORI', 'sangiovese e cabernet sauvignon']
# 628 ['TIGNANELLO', 'MARCHESI ANTINORI', 'sangiovese e cabernet sauvignon']
# 629 ['BRUNELLO DI MONTALCINO RISERVA', 'BIONDI SANTI', 'docg Brunello di Montalcino']
# 630 ['BRUNELLO DI MONTALCINO RISERVA', 'BIONDI SANTI', 'docg Brunello di Montalcino']
# 631 ['BRUNELLO DI MONTALCINO RISERVA', 'BIONDI SANTI', 'docg Brunello di Montalcino']
# 632 ['BRUNELLO DI MONTALCINO', 'VAL DI SUGA', 'docg Brunello di Montalcino']
# 633 ['BRUNELLO DI MONTALCINO', 'PARADISO DI MANFREDI', 'docg Brunello di Montalcino']
# 634 ['BRUNELLO DI MONTALCINO CASTELGIOCONDO', 'FRESCOBALDI', 'docg Brunello di Montalcino']
# 635 ['BRUNELLO DI MONTALCINO', 'POGGIO DI SOTTO', 'docg Brunello di Montalcino']
# 636 ['BRUNELLO DI MONTALCINO RISERVA', 'POGGIO DI SOTTO', 'docg Brunello di Montalcino']
# 638 ['BRUNELLO DI MONTALCINO TENUTA NUOVA', 'CASANOVA DI NERI', 'docg Brunello di Montalcino']
# 639 ['BRUNELLO DI MONTALCINO RIS. CERRETALTO', 'CASANOVA DI NERI', 'docg Brunello di Montalcino']
# 640 ['BRUNELLO DI MONTALCINO', 'SOLDERA', 'docg Brunello di Montalcino']
# 641 ['BRUNELLO DI MONTALCINO', 'SOLDERA', 'docg Brunello di Montalcino']
# 642 ['BRUNELLO DI MONTALCINO', 'SOLDERA', 'docg Brunello di Montalcino']
# 643 ['BRUNELLO DI MONTALCINO RISERVA MADONNA DELLE GRAZIE', 'docg Brunello di Montalcino', 'IL MARRONETO']
# 644 ['BRUNELLO DI MONTALCINO', 'MASTROJANNI', 'docg Brunello di Montalcino']
# 645 ['BRUNELLO DI MONTALCINO', 'MASTROJANNI', 'docg Brunello di Montalcino']
# 646 ['BRUNELLO DI MONTALCINO VIGNA LORETO', 'MASTROJANNI', 'docg Brunello di Montalcino']
# 647 ['BRUNELLO DI MONTALCINO', 'RIDOLFI', 'docg Brunello di Montalcino']
# 648 ['BRUNELLO DI MONTALCINO', 'RIDOLFI', 'docg Brunello di Montalcino']
# 649 ['BRUNELLO DI MONTALCINO PELAGRILLI', 'SIRO PACENTI', 'docg Brunello di Montalcino']
# 650 ['BRUNELLO DI MONTALCINO VIGNA MONTOSOLI', 'CANALICCHIO DI SOPRA', 'docg Brunello di Montalcino']
# 651 ['BRUNELLO DI MONTALCINO VIGNA MONTOSOLI', 'docg Brunello di Montalcino', 'CANALICCHIO DI SOPRA']
# 657 ["CA' MARCANDA", 'GAJA', 'Bolgheri doc']
# 658 ['MAGARI', 'GAJA', 'Bolgheri doc']
# 665 ['ORNELLAIA', "TENUTA DELL'ORNELLAIA", 'doc Bolgheri Superiore']
# 666 ['ORNELLAIA', "TENUTA DELL'ORNELLAIA", 'doc Bolgheri Superiore']
# 667 ['ORNELLAIA', "TENUTA DELL'ORNELLAIA", 'doc Bolgheri Superiore']
# 668 ['ORNELLAIA', "TENUTA DELL'ORNELLAIA", 'doc Bolgheri Superiore']
# 669 ['ORNELLAIA', "TENUTA DELL'ORNELLAIA", 'doc Bolgheri Superiore']
# 670 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 671 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 672 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 673 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 674 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 675 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 676 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 677 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 678 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 679 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 680 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 682 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 684 ['SASSICAIA', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 708 ['SAN LEONARDO', 'TENUTA SAN LEONARDO', 'da uve cab. sauv./franc e merlot']
# 709 ['SAN LEONARDO', 'TENUTA SAN LEONARDO', 'da uve cab. sauv./franc e merlot']
# 710 ['SAN LEONARDO', 'TENUTA SAN LEONARDO', 'da uve cab. sauv./franc e merlot']
# 713 ['CHATEAU HAUT-MARBUZET', 'DUBOSQ ET FILLS', 'Saint-Estephe']
# 714 ['CHATEAU DE PEZ', 'CHATEAU DE PEZ', 'Bordeaux AOC']
# 715 ['CHATEAU PALMER', 'CHATEAU PALMER', "me Cru Classe'"]
# 716 ['CHATEAU GISCOURS', 'CHATEAU GISCOURS', 'Margaux AOC']
# 717 ['CHATEAU HAUT BRION', 'CHATEAU HAUT BRION', '1er Grand Cru Classe']
# 718 ['CHATEAU HAUT BRION', 'CHATEAU HAUT BRION', '1er Grand Cru Classe']
# 719 ['CHATEAU PONTET CANET', 'CHATEAU PONTET CANET', "5eme Cru Classe'"]
# 720 ['CHATEAU DUHART-MILON', 'CHATEAU DUHART-MILON', "Grand Cru Classe'"]
# 721 ['ANSEILLAN', 'DOMAINE BARONS DE ROTHSCHILD', 'Bordeaux AOC']
# 722 ['CHATEAU HAUT-BATAILLEY', 'CHATEAU HAUT BATAILLEY', "5eme Cru Classe'"]
# 723 ['CHATEAU LAFITE ROTHSCHILD', 'DOMAINE BARONS DE ROTHSCHILD', '1er Cru Classe']
# 724 ['CHATEAU LATOUR', 'DOMAINE LATOUR', '1er Grand Cru Classe']
# 725 ['CHATEAU LAFITE ROTHSCHILD', 'DOMAINE BARONS DE ROTHSCHILD', '1er Cru Classe']
# 727 ['CHATEAU MOUTON ROTHSCHILD', 'MOUTON ROTHSCHILD', '1er Grand Cru Classe']
# 728 ['CHATEAU MOUTON ROTHSCHILD', 'MOUTON ROTHSCHILD', '1er Grand Cru Classe']
# 729 ['ESPERANCE DE TROTANOY', 'CHATEAU TROTANOY', 'Pomerol AOC']
# 730 ['CHATEAU LA FLEUR-PETRUS', 'CHATEAU LA FLEUR-PETRUS', 'Pomerol AOC']
# 731 ["CHATEAU L'EVANGILE", "CHATEAU L'EVANGILE", 'Pomerol AOC']
# 732 ['CHATEAU LA CONSEILLANTE', 'CHATEAU LA CONSEILLANTE', 'Pomerol AOC']
# 733 ['CHATEAU LAFLEUR-GAZIN', 'LAFLEUR-GAZIN', 'Pomerol AOC']
# 734 ['CHATEAU LA GRAVE', 'TRIGANT DE BOISSET', 'Pomerol AOC']
# 735 ['CHATEAU LATOUR A POMEROL', 'CHATEAU LATOUR', 'Pomerol AOC']
# 736 ['PETRUS', 'PETRUS LACOSTE LOUBAT', 'Pomerol AOC']
# 737 ['PETRUS', 'PETRUS LACOSTE LOUBAT', 'Pomerol AOC']
# 738 ['PETRUS', 'PETRUS LACOSTE LOUBAT', 'Pomerol AOC']
# 739 ['CHATEAU CHEVAL BLANC', 'DOMAINE CHEVAL BLANC', '1er Grand Cru Classe']
# 741 ['BOURGOGNE', 'CUVEE N. 1', 'DOMINIQUE LAURENT']
# 742 ['BOURGOGNE', 'ROUGE', 'FAVELAY']
# 744 ['CHOREY LES BAUNE', 'DOMAINE TOLLOT-BEAUT', 'AOC Chorey les baune']
# 747 ['BOURGOGNE', 'ROUGE RETOUR DES FLANDRES', 'DOMINIQUE REGNARD']
# 748 ['GEVREY-CHAMBERTIN', 'PHILIPPE PACALET', 'AOC Gevrey-Chambertin']
# 749 ['GEVREY-CHAMBERTIN', 'DAVID DUBAND', 'AOC Gevrey-Chambertin']
# 750 ['GEVREY-CHAMBERTIN', 'CLAUDE DUGAT', 'AOC Gevrey-Chambertin']
# 751 ['GEVREY-CHAMBERTIN 1ER CRU LAVAUX SAIT-JACQUES', 'DENIS MORTET', 'AOC Gevrey-Chambertin']
# 752 ['GEVREY-CHAMBERTIN', 'DOMAINE MORTET ARNAUD', 'AOC Gevrey-Chambertin']
# 753 ['CHAMBERTIN', 'ARMAND ROUSSEAU', 'Grand Cru']
# 754 ['CHAMBERTIN', 'ARMAND ROUSSEAU', 'Grand Cru']
# 755 ['CHAMBERTIN', 'ARMAND ROUSSEAU', 'Grand Cru']
# 756 ['MAZIS-CHAMBERTIN', "LEROY-D'AUVENAY", 'Grand Cru']
# 759 ['CLOS DE LA ROCHE CUVEE VIEILLES VIGNES', 'DOMAINE PONSOT', 'Grand Cru']
# 762 ['CLOS DES LAMBRAYS', 'DOMAINE DES LAMBRAYS', 'Grand Cru']
# 763 ['CLOS DES LAMBRAYS', 'DOMAINE DES LAMBRAYS', 'Grand Cru']
# 764 ['CLOS DES TART', 'DOMAINE DU CLOS DE TART', 'Grand Cru']
# 765 ['CLOS DES TART', 'DOMAINE DU CLOS DE TART', 'Grand Cru']
# 767 ['CHAMBOLLE MUSIGNY', 'LES ATHETS', 'DOMAINE JEAN TARDY']
# 768 ['MUSIGNY VIELLES VIGNES', 'GEORGES DE VOGUE', 'Grand Cru']
# 769 ['MUSIGNY', 'FAIVELEY', 'Grand Cru']
# 770 ['CLOS DU VOUGEOT', 'FAIVELEY', 'Grand Cru']
# 771 ['CLOS DU VOUGEOT VIELLES VIGNES', 'PONSOT', 'Grand Cru']
# 772 ['CLOS DU VOUGEOT', 'CHATEAU DE LA TOUR', 'Grand Cru']
# 773 ['ECHEZEAUX', 'DOMAINE GROS FRERE ET SOEUR', 'Grand Cru']
# 776 ['LA ROMANEE', 'DOMAINE DU COMTE LIGER-BELAIR', 'Grand Cru']
# 777 ['ECHEZEAUX', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 778 ['GRANDS ECHEZEAUX', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 779 ['LA TACHE', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 780 ['RICHEBOURG', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 781 ['RICHEBOURG', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 782 ['ROMANEE-CONTI', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 783 ['ROMANEE-CONTI', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 784 ['ROMANEE-SAINT VIVANT', 'DOMAINE DE LA ROMANEE-CONTI', 'Grand Cru']
# 785 ['NUITS ST. GEORGES LES PORETS', 'FAIVELEY', 'a.c. Nuits St. Georges']
# 786 ['NUITS ST. GEORGES 1er CRU AUX BOUDOTS', 'MEO CAMUZET', 'a.c. Nuits St. Georges']
# 787 ['NUITS ST. GEORGES 1er CRU LES CRAS', 'COMTE LIGER-BELAIR', 'a.c. Nuits St. Georges']
# 789 ['ALOXE-CORTON ROUGE “LES FOURNIERES”', 'TOLLOT-BEAUT', 'AOC Aloxe-Corton']
# 790 ['POMMARD 1ER CRU LES EPENOTS', 'ROSSIGNOL', 'AOC Pommard']
# 791 ['POMMARD 1ER CRU VIELLES VIGNE', 'DOMINIQUE LAURENT', 'AOC Pommard']
# 792 ['POMMARD', 'DOMAINE ROY JACQUELINE', 'AOC Pommard']
# 793 ['VOLNAY', 'DOMINIQUE LAURENT', 'AOC Volnay']
# 794 ['VOLNAY', 'DOMAINE BOULEY', 'AOC Volnay']
# 797 ["CHINON ''VIELLES VIGNES''", 'PATRIK LAMBERT', 'Chinon AOC']
# 798 ['CHATEAUNEUF-DU-PAPE ROUGE', 'CHATEAU GIGOGNAN', 'Chateauneuf-du-Pape AOC']
# 799 ['CHATEAUNEUF-DU-PAPE ROUGE LES SINARDS', 'FAMILLE PERRIN', 'Chateauneuf-du-Pape AOC']
# 805 ['CLOS DE GAMOT CAHORS', 'CLOS DE GAMOT', 'Cahors AOC']
# 806 ['CAHORS MALBEC', 'CHATEAU PONZAC', 'Cahors AOC']
# 815 ['HARLAN ESTATE', 'HARLAN', 'ESTATE']
# 819 ['PASSITO MONDESERTO', 'AGOSTINETTO', 'uve prosecco passite']
# 820 ['PASSITO MONDESERTO', 'AGOSTINETTO', 'uve prosecco passite']
# 825 ["MARSALA RISERVA ''AEGUSA'' SEMISECCO", 'FLORIO', 'doc Marsala']
# 826 ["MARSALA RISERVA ''DONNAFRANCA'' SEMISECCO", 'FLORIO', 'doc Marsala']
# 827 ['MALAVASIA DELLE LIPARI', 'CARAVAGLIO', 'Pantelleria Doc']
# 828 ["BEN RYE'", 'DONNAFUGATA', 'Pantelleria Doc']
# 831 ['SAUTERNES CHAT. HAUT-PEYRAGUEY 1ER CRU CLASSE', 'HAUT-PEYRAGUEY', 'aoc Sauternes']
# 832 ["SAUTERNES CHAT. D'YQUEM", 'LUR SALUCES', 'aoc Sauternes']
# 833 ["SAUTERNES CHAT. FILHOT GRAND CRU CLASSE'", 'DOMAINE FILHOT', 'aoc Sauternes']
# 834 ['SAUTERNES CHATEAU LIOT', 'DOMAINE LIOT', 'aoc Sauternes']
# 835 ["SAUTERNES CHATEAU SUDUIRAUT 1ER CRU CLASSE'", 'CHATEAU SUDUIRAUT', 'aoc Sauternes']
# 388

# %%
# sanity check on naming: length greater or equal to 4
for i, info in enumerate(wine_info):
    if len(info['naming']) >= 4:
        print(i, info['naming'])
# Out:
# 45 ['BRUT FRANCIACORTA ALMA', 'GRANDE CUVEE', 'BELLAVISTA', 'docg Franciacorta']
# 47 ['BRUT FRANCIACORTA ALMA', 'GRANDE CUVEE', 'BELLAVISTA', 'docg Franciacorta']
# 48 ['BRUT FRANCIACORTA ALMA', 'GRANDE CUVEE', 'BELLAVISTA', 'docg Franciacorta']
# 60 ['PROSECCO', 'EXTRA DRY', 'TORRESELLA', 'Prosecco Doc']
# 95 ['CRISTAL', 'BRUT', 'LOUIS ROEDERER', 'Louis Roederer']
# 96 ['CRISTAL', 'BRUT', 'LOUIS ROEDERER', 'Louis Roederer']
# 97 ['CRISTAL', 'BRUT', 'LOUIS ROEDERER', 'Louis Roederer']
# 98 ['CRISTAL', 'BRUT', 'ROSE’', 'LOUIS ROEDERER', 'Louis Roederer']
# 263 ['SAUVIGNON', 'RUTTARS', 'VILLA PARENS', 'Venezia Giulia Igp']
# 280 ['RADICI', 'FIANO DI AVELLINO RIS.', 'MASTROBERARDINO', 'Docg']
# 308 ['ORNELLAIA', 'BIANCO', "TENUTA DELL'ORNELLAIA", 'Sauvignon Blanc e Viognier']
# 309 ['ORNELLAIA', 'BIANCO', "TENUTA DELL'ORNELLAIA", 'Sauvignon Blanc e Viognier']
# 359 ['PULIGNY-MONTRACHET 1er CRU', 'LES FOLATIERES', 'a. Puligny Montrachet c.', 'DOMAINE ALAIN CHAVY']
# 366 ['PULIGNY-MONTRACHET 1er CRU', 'SOUS LES PUITS', 'LOUIS LATOUR', 'a. Puligny Montrachet c.']
# 408 ['RIESLING', 'KABINETT HALB TROCKEN', 'SCHLOSS', 'JOHANNISBERG']
# 409 ['RIESLING', 'GELBLOCK', 'SCHLOSS', 'JOHANNISBERG']
# 414 ['RIESLING', 'GIMMELDINGEN', 'TROCKEN', 'MULLER-CATOIR']
# 498 ['BARBARESCO', 'RABAJA’', 'CORTESE', 'docg Barbaresco']
# 499 ['BARBARESCO', 'RABAJA’', 'CORTESE', 'docg Barbaresco']
# 500 ['BARBARESCO', 'RABAJA’', 'CORTESE', 'docg Barbaresco']
# 505 ['BAROLO CA’ D MORISSIO RISERVA', 'GIUSEPPE', 'MASCARELLO', 'docg Barolo']
# 506 ['BAROLO MONPRIVATO', 'GIUSEPPE', 'MASCARELLO', 'docg Barolo']
# 507 ['BAROLO MONPRIVATO', 'GIUSEPPE', 'MASCARELLO', 'docg Barolo']
# 518 ['BAROLO PERNO VIGNA SANTO STEFANO', 'GIUSEPPE', 'MASCARELLO', 'docg Barolo']
# 519 ['BAROLO VILLERO', 'GIUSEPPE', 'MASCARELLO', 'docg Barolo']
# 530 ['BAROLO', 'CASTIGLIONE', 'VIETTI', 'docg Barolo']
# 531 ['BAROLO', 'LAZZARITO', 'VIETTI', 'docg Barolo']
# 606 ['FLACCIANELLO DELLA PIEVE', 'BIO', 'FONTODI', 'da uve sangiovese']
# 607 ['FLACCIANELLO DELLA PIEVE', 'BIO', 'FONTODI', 'da uve sangiovese']
# 637 ['BRUNELLO DI MONTALCINO', 'LUCE', 'TENUTA LUCE MONTALCINO', 'docg Brunello di Montalcino']
# 681 ['SASSICAIA', 'Doppio Magnum', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 683 ['SASSICAIA', 'Doppio Magnum', 'TENUTA SAN GUIDO', 'doc Bolgheri']
# 711 ['SAN LEONARDO', '6 l', 'TENUTA SAN LEONARDO', 'da uve cab. sauv./franc e merlot']
# 795 ['VOLNAY', '1ER CRU LES FREMIETS', 'DOMAINE BOILLOT', 'AOC Volnay']

# %%
# sanity check on naming: price is in the name
for i, info in enumerate(wine_info):
    if any(character.isdigit() for character in info['naming'][-1]):
        print(i, info)

# correct naming: 20072000022
# some have the price in the name, because there are 2 spaces between € and the price
# i correct this in v1-cleaned.txt, so they do not appear here
# the remaining ones are fine
# Out:
# 717 {'naming': ['CHATEAU HAUT BRION', 'CHATEAU HAUT BRION', '1er Grand Cru Classe'], 'format': 'standard', 'years': ['2019'], 'price': ['€ 1.000,00']}
# 718 {'naming': ['CHATEAU HAUT BRION', 'CHATEAU HAUT BRION', '1er Grand Cru Classe'], 'format': 'standard', 'years': ['2000'], 'price': ['€ 1.780,00']}
# 719 {'naming': ['CHATEAU PONTET CANET', 'CHATEAU PONTET CANET', "5eme Cru Classe'"], 'format': 'standard', 'years': ['2020'], 'price': ['€ 200,00']}
# 722 {'naming': ['CHATEAU HAUT-BATAILLEY', 'CHATEAU HAUT BATAILLEY', "5eme Cru Classe'"], 'format': 'standard', 'years': ['2016'], 'price': ['€ 180,00']}
# 723 {'naming': ['CHATEAU LAFITE ROTHSCHILD', 'DOMAINE BARONS DE ROTHSCHILD', '1er Cru Classe'], 'format': 'standard', 'years': ['2000'], 'price': ['€ 2.200,00']}
# 724 {'naming': ['CHATEAU LATOUR', 'DOMAINE LATOUR', '1er Grand Cru Classe'], 'format': 'standard', 'years': ['2000'], 'price': ['€ 1.800,00']}
# 725 {'naming': ['CHATEAU LAFITE ROTHSCHILD', 'DOMAINE BARONS DE ROTHSCHILD', '1er Cru Classe'], 'format': 'standard', 'years': ['1998'], 'price': ['€ 1.600,00']}
# 727 {'naming': ['CHATEAU MOUTON ROTHSCHILD', 'MOUTON ROTHSCHILD', '1er Grand Cru Classe'], 'format': 'standard', 'years': ['1988'], 'price': ['€ 1.400,00']}
# 728 {'naming': ['CHATEAU MOUTON ROTHSCHILD', 'MOUTON ROTHSCHILD', '1er Grand Cru Classe'], 'format': 'standard', 'years': ['1983'], 'price': ['€ 1.200,00']}
# 739 {'naming': ['CHATEAU CHEVAL BLANC', 'DOMAINE CHEVAL BLANC', '1er Grand Cru Classe'], 'format': 'standard', 'years': ['2000'], 'price': ['€ 1.550,00']}

# %% [markdown]
# # Create v2-cleaned.csv

# %%
for info in wine_info:
    if len(info['naming']) == 2:
        info['name'] = info['naming'][0]
        info['winery_name'] = info['naming'][1]
    elif len(info['naming']) == 3:
        info['name'] = info['naming'][0]
        info['winery_name'] = info['naming'][1]
        info['denomination'] = info['naming'][2]
    else:
        info['name'] = info['naming'][0] + ' ' + info['naming'][1]
        info['winery_name'] = info['naming'][2]
        info['denomination'] = info['naming'][3]

# %%
import copy

wines = pd.DataFrame(wine_info)
wines = wines.drop('naming', axis=1)
wines = wines.explode('years')
wines = wines.explode('price')

wines_original = copy.deepcopy(wines)

wines
# Out:
#        format years     price                                       name  \
# 0    standard   S/A   € 90,00                    RUINART BLANC DE BLANCS
# 1    standard   S/A   € 90,00                              RUINART ROSE'
# 2    standard   S/A   € 65,00                  EXTRA BRUT PREMIERE CUVEE
# 3    standard   S/A   € 75,00                             BRUT CHAMPAGNE
# 4    standard   S/A   € 60,00  BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS
# ..        ...   ...       ...                                        ...
# 839  standard   S/A     € ,00                    SHERRY PX PEDRO XIMENEZ
# 840  standard   S/A   € 40,00                      PORTO RESERVA ADRIANO
# 841  standard  2008  € 140,00                    TOKAJI ASZU 5 PUTTONIOS
# 842  standard  2016   € 90,00                    TOKAJI ASZU 3 PUTTONIOS
# 843  standard  2016     € ,00                    TOKAJI ASZU 5 PUTTONIOS
#
#               winery_name denomination
# 0                 RUINART          NaN
# 1                 RUINART          NaN
# 2          BRUNO PAILLARD          NaN
# 3           SPECIAL CUVEE    BOLLINGER
# 4         PERTOIS MORISET          NaN
# ..                    ...          ...
# 839  FERNANDO DE CASTILLA          NaN
# 840           RAMOS PINTO          NaN
# 841          SAMUEL TINON          NaN
# 842                OREMUS          NaN
# 843                PAJZOS          NaN
#
# [993 rows x 6 columns]

# %% [markdown]
# ## Create standard fields

# %% [markdown]
# required fields:
#
#  - `external_id`: missing
#  - `name`: OK
#  - `winery_name`: OK
#  - `type`: missing
#  - `storage_area`: missing
#  - `size`: create from `format`
#  - `vintage`: create from `years`
#  - `price`: to parse
#  - `info`: missing
#  - `quantity`: missing
#  - `internal_notes`: missing

# %%
# - `external_id`: missing
wines['external_id'] = wines.index + 1
wines.head()
# Out:
#      format years    price                                       name  \
# 0  standard   S/A  € 90,00                    RUINART BLANC DE BLANCS
# 1  standard   S/A  € 90,00                              RUINART ROSE'
# 2  standard   S/A  € 65,00                  EXTRA BRUT PREMIERE CUVEE
# 3  standard   S/A  € 75,00                             BRUT CHAMPAGNE
# 4  standard   S/A  € 60,00  BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS
#
#        winery_name denomination  external_id
# 0          RUINART          NaN            1
# 1          RUINART          NaN            2
# 2   BRUNO PAILLARD          NaN            3
# 3    SPECIAL CUVEE    BOLLINGER            4
# 4  PERTOIS MORISET          NaN            5

# %%
#  - `name`: OK
#  - `winery_name`: OK
#  - `type`: missing
wines['type'] = ''
wines.head()
# Out:
#      format years    price                                       name  \
# 0  standard   S/A  € 90,00                    RUINART BLANC DE BLANCS
# 1  standard   S/A  € 90,00                              RUINART ROSE'
# 2  standard   S/A  € 65,00                  EXTRA BRUT PREMIERE CUVEE
# 3  standard   S/A  € 75,00                             BRUT CHAMPAGNE
# 4  standard   S/A  € 60,00  BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS
#
#        winery_name denomination  external_id type
# 0          RUINART          NaN            1
# 1          RUINART          NaN            2
# 2   BRUNO PAILLARD          NaN            3
# 3    SPECIAL CUVEE    BOLLINGER            4
# 4  PERTOIS MORISET          NaN            5

# %%
#  - `storage_area`: missing
wines['storage_area'] = ''
wines.head()
# Out:
#      format years    price                                       name  \
# 0  standard   S/A  € 90,00                    RUINART BLANC DE BLANCS
# 1  standard   S/A  € 90,00                              RUINART ROSE'
# 2  standard   S/A  € 65,00                  EXTRA BRUT PREMIERE CUVEE
# 3  standard   S/A  € 75,00                             BRUT CHAMPAGNE
# 4  standard   S/A  € 60,00  BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS
#
#        winery_name denomination  external_id type storage_area
# 0          RUINART          NaN            1
# 1          RUINART          NaN            2
# 2   BRUNO PAILLARD          NaN            3
# 3    SPECIAL CUVEE    BOLLINGER            4
# 4  PERTOIS MORISET          NaN            5

# %%
wines['format'].unique()
# Out:
# array(['standard', 'Magnum', 'Doppio Magnum', '6L', 'Piccolo'],
#       dtype=object)

# %%
#  - `size`: create from `format`

# map automatically
size_mapping = {
    'Piccolo': 'HALF_BOTTLE',
    'standard': 'BOTTLE',
    'Magnum': 'MAGNUM',
    'Doppio Magnum': 'JEROBOAM',
    '6L': 'MATHUSALEM',
}
wines['size'] = wines['format'].map(size_mapping)

# map manually the first ones
wines.loc[range(0, 7), 'size'] = 'HALF_BOTTLE'
wines.head(8)
# Out:
#      format years    price                                       name  \
# 0  standard   S/A  € 90,00                    RUINART BLANC DE BLANCS
# 1  standard   S/A  € 90,00                              RUINART ROSE'
# 2  standard   S/A  € 65,00                  EXTRA BRUT PREMIERE CUVEE
# 3  standard   S/A  € 75,00                             BRUT CHAMPAGNE
# 4  standard   S/A  € 60,00  BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS
# 5  standard   S/A  € 65,00               BRUT ROEDERER COLLECTION 244
# 6  standard   S/A  € 36,00                 EXTRA BRUT CUVEE' MARIANNA
# 7  standard  2020    € ,00                         CORTON CHARLEMAGNE
#
#           winery_name    denomination  external_id type storage_area  \
# 0             RUINART             NaN            1
# 1             RUINART             NaN            2
# 2      BRUNO PAILLARD             NaN            3
# 3       SPECIAL CUVEE       BOLLINGER            4
# 4     PERTOIS MORISET             NaN            5
# 5      LOUIS ROEDERER  Louis Roederer            6
# 6              ARUNDA             NaN            7
# 7  BONNEAU DU MARTRAY       Grand Cru            8
#
#           size
# 0  HALF_BOTTLE
# 1  HALF_BOTTLE
# 2  HALF_BOTTLE
# 3  HALF_BOTTLE
# 4  HALF_BOTTLE
# 5  HALF_BOTTLE
# 6  HALF_BOTTLE
# 7       BOTTLE

# %%
#  - `vintage`: create from `years`
wines['vintage'] = wines['years']

# %%
#  - `price`: to parse
import re

def parse_price(price):
    orginal_price = price
    try:
        price = price.replace('.','').replace(',','.')
        price = price.replace('€', '').replace(' ', '').strip()
        price = re.sub(r'€\s*', '', price)
        price = re.sub(r'^\W+|\W+$', '', price)
        return float(price if price else 0)
    except Exception as e:
        print(f"Error parsing price: {orginal_price}")
        return orginal_price

print('applying parse_price')
wines['price'] = wines_original['price'].apply(parse_price)

print('\nmanually correcting prices that were not parsed correctly:')
wines.loc[wines_original['price'] == '€ 65,00 ,00', 'price'] = 65.0
wines.loc[wines_original['price'] == '€ 140,00 ,00', 'price'] = 140.0
print('done.')

wines['price'] = wines['price'].astype(float)
wines.head()
# Out:
# applying parse_price
# Error parsing price: € 65,00 ,00
# Error parsing price: € 140,00 ,00
#
# manually correcting prices that were not parsed correctly:
# done.
#      format years  price                                       name  \
# 0  standard   S/A   90.0                    RUINART BLANC DE BLANCS
# 1  standard   S/A   90.0                              RUINART ROSE'
# 2  standard   S/A   65.0                  EXTRA BRUT PREMIERE CUVEE
# 3  standard   S/A   75.0                             BRUT CHAMPAGNE
# 4  standard   S/A   60.0  BRUT CHAMP. GRAND CRU B&B QUATRE TERROIRS
#
#        winery_name denomination  external_id type storage_area         size  \
# 0          RUINART          NaN            1                    HALF_BOTTLE
# 1          RUINART          NaN            2                    HALF_BOTTLE
# 2   BRUNO PAILLARD          NaN            3                    HALF_BOTTLE
# 3    SPECIAL CUVEE    BOLLINGER            4                    HALF_BOTTLE
# 4  PERTOIS MORISET          NaN            5                    HALF_BOTTLE
#
#   vintage
# 0     S/A
# 1     S/A
# 2     S/A
# 3     S/A
# 4     S/A

# %%
#  - `info`: missing
wines['info'] = ''

# %%
#  - `quantity`: missing
wines['quantity'] = 0

# %%
#  - `internal_notes`: missing
wines['internal_notes'] = ''

# %% [markdown]
# ## Create v2 files

# %%
wines_out = wines[['external_id', 'name', 'winery_name', 'type', 'storage_area', 'size', 'vintage', 'price', 'info', 'quantity', 'internal_notes']]

open('v2-cleaned.csv', 'w').close()
wines_out.to_csv('v2-cleaned.csv', index=False)

# %%
with open('search-terms.txt', 'w') as f:
    for term in wines['name'].unique():
        f.write(f'{term}\n')
    for term in wines['winery_name'].unique():
        f.write(f'{term}\n')
