# %%
import sys
sys.path.append('../../')
import os

import pandas as pd
from utils import fill_empty, VColumns
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 6
#       3 import os
#       5 import pandas as pd
# ----> 6 from utils import fill_empty, VColumns
#       7 from dotenv import load_dotenv
#       8 load_dotenv()
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# # Load input file

# %%
df1 = pd.read_csv("v1-start.csv")
df1.head()
# Out:
#    storage_area type size                        name information      dosage  \
# 0             4  NaN  NaN                    RED MOON         NaN         NaN
# 1             5  NaN  NaN             Cuvée Marianna          NaN  Extra Brut
# 2             6  NaN  NaN  Arunda Riserva Millesimato         NaN  Extra Brut
# 3             7  NaN  NaN                Arunda Rosé          NaN        Brut
# 4             8  NaN  NaN           Comitissa Riserva         NaN    Pas Dosé
#
#       winery_name  vintage  eur_purchase_price  quantity other_vintages  \
# 0             NaN      NaN                 NaN       5.0            NaN
# 1  Arunda Vivaldi      NaN                22.5       3.0            NaN
# 2  Arunda Vivaldi   2016.0                25.0       2.0         2017-1
# 3  Arunda Vivaldi      NaN                20.5       NaN            NaN
# 4  Lorenz Martini   2018.0                22.5       2.0         2019-2
#
#    visible unclear  eur_sales_price  glass_price internal_notes
# 0        1     NaN              NaN          NaN            NaN
# 1        1     NaN             73.0         12.0            NaN
# 2        1     NaN             81.0         13.0            NaN
# 3        1     NaN             67.0         11.0            NaN
# 4        1     NaN             73.0         12.0            NaN

# %% [markdown]
# ### Split vintages into multiple wines

# %%
import re
regex = r"\d{4}-\d{1,2}"

# read column `other_vintages` and if there are other vintages specified, copy the line and add the other vintages
for i, row in df1.iterrows():
    if pd.notna(row['other_vintages']):
        # read vintages that match the regex and add them to the dataframe
        other_vintages = [v for v in row['other_vintages'] if re.match(regex, v)]
        for v in other_vintages:
            new_row = row.copy()
            new_row['vintage'] = v
            new_row['visible'] = False
            df1 = df1.append(new_row)

# %% [markdown]
# # Start elaborating columns
#
# Create a new dataframe with empty values, so that we can start filling in values from the input dataframe, without overriding columns.

# %%
df1.head()
# Out:
#    storage_area type size                        name information      dosage  \
# 0             4  NaN  NaN                    RED MOON         NaN         NaN
# 1             5  NaN  NaN             Cuvée Marianna          NaN  Extra Brut
# 2             6  NaN  NaN  Arunda Riserva Millesimato         NaN  Extra Brut
# 3             7  NaN  NaN                Arunda Rosé          NaN        Brut
# 4             8  NaN  NaN           Comitissa Riserva         NaN    Pas Dosé
#
#       winery_name  vintage  eur_purchase_price  quantity other_vintages  \
# 0             NaN      NaN                 NaN       5.0            NaN
# 1  Arunda Vivaldi      NaN                22.5       3.0            NaN
# 2  Arunda Vivaldi   2016.0                25.0       2.0         2017-1
# 3  Arunda Vivaldi      NaN                20.5       NaN            NaN
# 4  Lorenz Martini   2018.0                22.5       2.0         2019-2
#
#    visible unclear  eur_sales_price  glass_price internal_notes
# 0        1     NaN              NaN          NaN            NaN
# 1        1     NaN             73.0         12.0            NaN
# 2        1     NaN             81.0         13.0            NaN
# 3        1     NaN             67.0         11.0            NaN
# 4        1     NaN             73.0         12.0            NaN

# %%
# create new empty dataframe
df = pd.DataFrame(columns=VColumns.v2())
df.head()
# Out:
# Empty DataFrame
# Columns: [external_id, type, name, winery_name, info, size, vintage, price, purchase_price, quantity, storage_area, internal_notes]
# Index: []

# %%
# copy values from original columns to new columns
df['external_id'] = df1['storage_area'].apply(lambda x: str(x).zfill(4))
df['type'] = df1['type']
df['name'] = df1['name'] + " " + df1['dosage'].fillna("")
df['winery_name'] = df1['winery_name']
df["vintage"] = df1["vintage"]
df["quantity"] = df1["quantity"]

# fill to 4 digits
df["storage_area"] = df1["storage_area"].apply(lambda x: str(x).zfill(4))
df["internal_notes"] = df1['glass_price'].apply(lambda x: f"Glas Preis: {x}\n\n" if not pd.isnull(x) else "") + df1['internal_notes'].fillna("")
df["visible"] = df1["visible"]

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # copy values from original columns to new columns
# ----> 2 df['external_id'] = df1['storage_area'].apply(lambda x: str(x).zfill(4))
#       3 df['type'] = df1['type']
#       4 df['name'] = df1['name'] + " " + df1['dosage'].fillna("")
#
# NameError: name 'df1' is not defined

# %%
# size
df['size'] = df1["size"].fillna("BOTTLE")

# convert prices to cents
df['price'] = df1['eur_sales_price'].apply(lambda x: int(x*100) if not pd.isnull(x) else 0) # convert to cents
df['purchase_price'] = df1['eur_purchase_price'].apply(lambda x: int(x*100) if not pd.isnull(x) else 0) # convert to cents

df.head()
# Out:
#    external_id type                                   name     winery_name  \
# 0            4  NaN                              RED MOON              NaN
# 1            5  NaN             Cuvée Marianna  Extra Brut  Arunda Vivaldi
# 2            6  NaN  Arunda Riserva Millesimato Extra Brut  Arunda Vivaldi
# 3            7  NaN                      Arunda Rosé  Brut  Arunda Vivaldi
# 4            8  NaN             Comitissa Riserva Pas Dosé  Lorenz Martini
#
#   info    size  vintage  price  purchase_price  quantity storage_area  \
# 0  NaN  BOTTLE      NaN      0               0       5.0         0004
# 1  NaN  BOTTLE      NaN   7300            2250       3.0         0005
# 2  NaN  BOTTLE   2016.0   8100            2500       2.0         0006
# 3  NaN  BOTTLE      NaN   6700            2050       NaN         0007
# 4  NaN  BOTTLE   2018.0   7300            2250       2.0         0008
#
#          internal_notes  visible
# 0                              1
# 1  Glas Preis: 12.0\n\n        1
# 2  Glas Preis: 13.0\n\n        1
# 3  Glas Preis: 11.0\n\n        1
# 4  Glas Preis: 12.0\n\n        1

# %%
df = fill_empty(df, VColumns.v2(), False)
df.head()
# Out:
#   external_id type                                   name     winery_name  \
# 0           4                                   RED MOON
# 1           5                  Cuvée Marianna  Extra Brut  Arunda Vivaldi
# 2           6       Arunda Riserva Millesimato Extra Brut  Arunda Vivaldi
# 3           7                           Arunda Rosé  Brut  Arunda Vivaldi
# 4           8                  Comitissa Riserva Pas Dosé  Lorenz Martini
#
#   info    size  vintage  price  purchase_price  quantity storage_area  \
# 0       BOTTLE        0      0               0         5         0004
# 1       BOTTLE        0   7300            2250         3         0005
# 2       BOTTLE     2016   8100            2500         2         0006
# 3       BOTTLE        0   6700            2050         0         0007
# 4       BOTTLE     2018   7300            2250         2         0008
#
#          internal_notes  visible
# 0                              1
# 1  Glas Preis: 12.0\n\n        1
# 2  Glas Preis: 13.0\n\n        1
# 3  Glas Preis: 11.0\n\n        1
# 4  Glas Preis: 12.0\n\n        1

# %% [markdown]
# # Merge files and write output
#
# If there are multiple files, merge them into one and create single output file.

# %%
df.head()

df_out = pd.concat([df], ignore_index=True)
df_out.to_csv("v2-cleaned.csv", index=False)

bool()
